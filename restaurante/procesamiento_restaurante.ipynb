# %% [markdown]
# <a href="https://colab.research.google.com/github/ferperezh/IIC3633_ProyectoMetricaDiversidad/blob/main/procesamiento_restaurante.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Procesamiento del Dataset de Restaurantes
# Este notebook realiza el análisis del dataset de restaurantes de Yelp, calculando las categorías más visitadas por usuario y evaluando métricas de diversidad como el Top-k por usuario.

# %%
from google.colab import drive

# Montar Google Drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-2-be4d8b56dd2c> in <cell line: 4>()
#       2
#       3 # Montar Google Drive
# ----> 4 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Cargar el dataset filtrado
#data_path = '/content/drive/MyDrive/IIC3633-2024-2/Restaurante/yelp_dataset/restaurant_sample.csv'
data_path = 'restaurant_sample.csv'
restaurant_data = pd.read_csv(data_path)

# Mostrar las primeras filas
print('Dataset cargado:')
restaurant_data.head()
# Out:
# Dataset cargado:
#               business_id                  name              address  \
# 0  11HXgzo47w5e5pziFXpTNg  Market 16 Noodle Bar       34TH Market St
# 1  -_mCgBtlEGbzbTsjnuXm3Q  Little Caesars Pizza       5207 Walnut St
# 2  V41hJnfJSAad4L_YdVQBGQ                 Zen Q     10807 Jasper Ave
# 3  -m_fl--6j4DFv1RlOtuL1g  Sukhothai Restaurant  11525 104 Avenue NW
# 4  QYnfbwG2fDfuWAI6RbGz4g          Craft & Claw      126 Chestnut St
#
#            city state postal_code   latitude   longitude  stars  review_count  \
# 0  Philadelphia    PA       19104  39.955696  -75.191610    1.5            39
# 1  Philadelphia    PA       19139  39.957348  -75.225982    2.0             5
# 2      Edmonton    AB     T5J 5G9  53.540780 -113.507118    4.0            12
# 3      Edmonton    AB     T5K 2S2  53.545830 -113.520614    3.0            24
# 4  Philadelphia    PA       19106  39.948092  -75.143565    4.0            30
#
#    is_open                                         attributes  \
# 0        0  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 1        1  {'Ambience': "{'touristy': False, 'hipster': F...
# 2        1  {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
# 3        0  {'HasTV': 'False', 'RestaurantsReservations': ...
# 4        0  {'OutdoorSeating': 'False', 'GoodForKids': 'Fa...
#
#                                           categories  \
# 0  Food, Noodles, Specialty Food, Ethnic Food, Im...
# 1                                 Pizza, Restaurants
# 2  Desserts, Restaurants, Taiwanese, Bubble Tea, ...
# 3                                  Thai, Restaurants
# 4                               Seafood, Restaurants
#
#                                                hours
# 0  {'Monday': '10:0-20:0', 'Tuesday': '10:0-20:0'...
# 1                                                NaN
# 2  {'Monday': '0:0-0:0', 'Tuesday': '11:0-22:0', ...
# 3  {'Monday': '17:0-21:30', 'Tuesday': '17:0-21:3...
# 4  {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...

# %%
# Dividir las categorías múltiples en filas separadas
restaurant_data_expanded = restaurant_data.assign(
    category=restaurant_data['categories'].str.split(', ')
).explode('category')

# Mostrar el dataset procesado
print('Dataset con categorías separadas:')
restaurant_data_expanded.head()
# Out:
# Dataset con categorías separadas:
#               business_id                  name         address          city  \
# 0  11HXgzo47w5e5pziFXpTNg  Market 16 Noodle Bar  34TH Market St  Philadelphia
# 0  11HXgzo47w5e5pziFXpTNg  Market 16 Noodle Bar  34TH Market St  Philadelphia
# 0  11HXgzo47w5e5pziFXpTNg  Market 16 Noodle Bar  34TH Market St  Philadelphia
# 0  11HXgzo47w5e5pziFXpTNg  Market 16 Noodle Bar  34TH Market St  Philadelphia
# 0  11HXgzo47w5e5pziFXpTNg  Market 16 Noodle Bar  34TH Market St  Philadelphia
#
#   state postal_code   latitude  longitude  stars  review_count  is_open  \
# 0    PA       19104  39.955696  -75.19161    1.5            39        0
# 0    PA       19104  39.955696  -75.19161    1.5            39        0
# 0    PA       19104  39.955696  -75.19161    1.5            39        0
# 0    PA       19104  39.955696  -75.19161    1.5            39        0
# 0    PA       19104  39.955696  -75.19161    1.5            39        0
#
#                                           attributes  \
# 0  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 0  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 0  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 0  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 0  {'BusinessAcceptsCreditCards': 'True', 'Restau...
#
#                                           categories  \
# 0  Food, Noodles, Specialty Food, Ethnic Food, Im...
# 0  Food, Noodles, Specialty Food, Ethnic Food, Im...
# 0  Food, Noodles, Specialty Food, Ethnic Food, Im...
# 0  Food, Noodles, Specialty Food, Ethnic Food, Im...
# 0  Food, Noodles, Specialty Food, Ethnic Food, Im...
#
#                                                hours        category
# 0  {'Monday': '10:0-20:0', 'Tuesday': '10:0-20:0'...            Food
# 0  {'Monday': '10:0-20:0', 'Tuesday': '10:0-20:0'...         Noodles
# 0  {'Monday': '10:0-20:0', 'Tuesday': '10:0-20:0'...  Specialty Food
# 0  {'Monday': '10:0-20:0', 'Tuesday': '10:0-20:0'...     Ethnic Food
# 0  {'Monday': '10:0-20:0', 'Tuesday': '10:0-20:0'...   Imported Food

# %%
list(restaurant_data_expanded['category'].unique())
# Out:
# ['Food',
#  'Noodles',
#  'Specialty Food',
#  'Ethnic Food',
#  'Imported Food',
#  'Sushi Bars',
#  'Restaurants',
#  'Pizza',
#  'Desserts',
#  'Taiwanese',
#  'Bubble Tea',
#  'Thai',
#  'Seafood',
#  'American (New)',
#  'Diners',
#  'Breakfast & Brunch',
#  'Cafes',
#  'Delis',
#  'Sandwiches',
#  'Fast Food',
#  'Grocery',
#  'Bagels',
#  'Bars',
#  'Nightlife',
#  'American (Traditional)',
#  'Sports Bars',
#  'Steakhouses',
#  'Burgers',
#  'Caribbean',
#  'Salad',
#  'Cocktail Bars',
#  'Coffee & Tea',
#  'Mediterranean',
#  'Greek',
#  'Moroccan',
#  'Italian',
#  'Pasta Shops',
#  'Barbeque',
#  'Comfort Food',
#  'Tex-Mex',
#  'Mexican',
#  'Tacos',
#  'Kebab',
#  'Turkish',
#  'Food Trucks',
#  'Chicken Wings',
#  'Asian Fusion',
#  'Arts & Entertainment',
#  'Active Life',
#  'Arcades',
#  'Kids Activities',
#  'Indoor Playcentre',
#  'Chicken Shop',
#  'Pubs',
#  'Hotels & Travel',
#  'Beer Bar',
#  'Bed & Breakfast',
#  'Music Venues',
#  'Indian',
#  'Vegetarian',
#  'Food Delivery Services',
#  'Caterers',
#  'Event Planning & Services',
#  'Gluten-Free',
#  'Chinese',
#  'Venues & Event Spaces',
#  'Cheese Shops',
#  'Ice Cream & Frozen Yogurt',
#  'Juice Bars & Smoothies',
#  'Soup',
#  'Meat Shops',
#  'Japanese',
#  'Party & Event Planning',
#  'Middle Eastern',
#  'Lebanese',
#  'Bakeries',
#  'Cajun/Creole',
#  'Food Stands',
#  'Beer',
#  'Wine & Spirits',
#  'Wraps',
#  'Tapas/Small Plates',
#  'Cafeteria',
#  'Canadian (New)',
#  'Breweries',
#  'Brewpubs',
#  'Beer Gardens',
#  'Gelato',
#  'Ramen',
#  'Hotels',
#  'Golf',
#  'Dive Bars',
#  'Fish & Chips',
#  'Home & Garden',
#  'Contractors',
#  'Countertop Installation',
#  'Building Supplies',
#  'Professional Services',
#  'Kitchen & Bath',
#  'Home Services',
#  'Electronics',
#  'Security Systems',
#  'Shopping',
#  'African',
#  'South African',
#  'Buffets',
#  'Korean',
#  'Halal',
#  'Falafel',
#  'Laotian',
#  'Southern',
#  'Accountants',
#  'Convenience Stores',
#  'Automotive',
#  'Gas Stations',
#  'Soul Food',
#  'Wine Bars',
#  'Live/Raw Food',
#  'Wineries',
#  'Empanadas',
#  'Jazz & Blues',
#  'Tobacco Shops',
#  'Lounges',
#  'Yelp Events',
#  'Local Flavor',
#  'Hookah Bars',
#  'Vietnamese',
#  'Internet Cafes',
#  'Acai Bowls',
#  'Tabletop Games',
#  'Hobby Shops',
#  'Hawaiian',
#  'Florists',
#  'Photography Stores & Services',
#  'Drugstores',
#  'Flowers & Gifts',
#  'Tiki Bars',
#  'Pretzels',
#  'Hot Dogs',
#  'Do-It-Yourself Food',
#  'Gastropubs',
#  'Donuts',
#  'Latin American',
#  'Honduran',
#  'Irish',
#  'Cheesesteaks',
#  'German',
#  'Afghan',
#  'Modern European',
#  'Vegan',
#  'Shopping Centers',
#  'Hong Kong Style Cafe',
#  'Cantonese',
#  'Beverage Store',
#  'Gay Bars',
#  'Dominican',
#  'Peruvian',
#  'Brasseries',
#  'Bartenders',
#  'Custom Cakes',
#  'Party Equipment Rentals',
#  'Puerto Rican',
#  'Spanish',
#  'Portuguese',
#  'Cuban',
#  'Creperies',
#  'French',
#  'New Mexican Cuisine',
#  'Pakistani',
#  'Organic Stores',
#  'Piano Bars',
#  'Armenian',
#  'Basque',
#  'Tapas Bars',
#  'Seafood Markets',
#  'Boating',
#  'Fishing',
#  'Cinema',
#  'Himalayan/Nepalese',
#  'Hakka',
#  'Historical Tours',
#  'Tours',
#  'Irish Pub',
#  'Coffee Roasteries',
#  'Salvadoran',
#  'Cupcakes',
#  'Arabic',
#  'Szechuan',
#  'Food Court',
#  'Shaved Ice',
#  'Waffles',
#  'Argentine',
#  'Brewing Supplies',
#  'Kosher',
#  'Beaches',
#  'Festivals',
#  'Persian/Iranian',
#  'Chocolatiers & Shops',
#  'Wedding Planning',
#  'Bistros',
#  'Belgian',
#  'Real Estate',
#  'Apartments',
#  'Cideries',
#  'Karaoke',
#  'Motorcycle Dealers',
#  'Resorts',
#  'Street Vendors',
#  'Donairs',
#  'Poke',
#  'Eatertainment',
#  'Themed Cafes',
#  'Dim Sum',
#  'Public Services & Government',
#  'Libraries',
#  'Restaurant Supplies',
#  'Wholesale Stores',
#  'Fruits & Veggies',
#  'Wholesalers',
#  'Party Bus Rentals',
#  'Bus Tours',
#  'Bar Crawl',
#  'International Grocery',
#  'Farmers Market',
#  'Unofficial Yelp Events',
#  'Pop-Up Restaurants',
#  'Pan Asian',
#  'Bowling',
#  'Health Markets',
#  'Fitness & Instruction',
#  'Personal Chefs',
#  'Yoga',
#  'Banks & Credit Unions',
#  'Financial Services',
#  'Hot Pot',
#  'Smokehouse',
#  'Teppanyaki',
#  'Tea Rooms',
#  'Dance Clubs',
#  'Beauty & Spas',
#  'Day Spas',
#  'Butcher',
#  'Club Crawl',
#  'Cigar Bars',
#  'Pancakes',
#  'Pet Stores',
#  'Pets',
#  'Adult Entertainment',
#  'Shared Office Spaces',
#  'Local Services',
#  'Kitchen Supplies',
#  'Tableware',
#  'Naturopathic/Holistic',
#  'Doctors',
#  'Massage Therapy',
#  'Health & Medical',
#  'Massage',
#  'Ethiopian',
#  'Pool Halls',
#  'Bookstores',
#  'Books',
#  'Mags',
#  'Music & Video',
#  'Japanese Curry',
#  'Polish',
#  'Ukrainian',
#  'Russian',
#  'Malaysian',
#  'Cooking Schools',
#  'Specialty Schools',
#  'Education',
#  'Tattoo',
#  'Piercing',
#  'Jewelry',
#  'Art Galleries',
#  'Social Clubs',
#  'Comedy Clubs',
#  'Gift Shops',
#  'Adult',
#  'British',
#  'Mongolian',
#  'Bangladeshi',
#  'Performing Arts',
#  'Body Shops',
#  'Herbs & Spices',
#  'Shanghainese',
#  'Wine Tasting Room',
#  'Nicaraguan',
#  'Cannabis Dispensaries',
#  'Special Education',
#  'Gun/Rifle Ranges',
#  'Country Clubs',
#  'Mini Golf',
#  'Casinos',
#  'Ethnic Grocery',
#  'Cooking Classes',
#  'Arts & Crafts',
#  'Whiskey Bars',
#  'Flea Markets',
#  'Poutineries',
#  'Personal Shopping',
#  'Travel Services',
#  'Travel Agents',
#  'Religious Organizations',
#  'Austrian',
#  'Sicilian',
#  'Kiosk',
#  'Art Museums',
#  'Museums',
#  'Landmarks & Historical Buildings',
#  'Brazilian',
#  'Appliances & Repair',
#  'Crane Services',
#  'Heating & Air Conditioning/HVAC',
#  'Uzbek',
#  'IT Services & Computer Repair',
#  'Mobile Phone Repair',
#  'Colombian',
#  'Filipino',
#  'Patisserie/Cake Shop',
#  'Venezuelan',
#  'Scandinavian',
#  'Dinner Theater',
#  'Boat Charters',
#  'Serbo Croatian',
#  'Macarons',
#  'Burmese',
#  'Accessories',
#  "Women's Clothing",
#  "Children's Clothing",
#  'Fashion',
#  'Scottish',
#  'Fondue',
#  'Dry Cleaning & Laundry',
#  'Singaporean',
#  'Wigs',
#  'Distilleries',
#  'Appliances',
#  'Hindu Temples',
#  'Olive Oil',
#  'Herbal Shops',
#  'Popcorn Shops',
#  'Izakaya',
#  'Party Supplies',
#  'Party Characters',
#  'Web Design',
#  'Mass Media',
#  'Print Media',
#  'Gyms',
#  'Preschools',
#  'Playgrounds',
#  'Painters',
#  'Plumbing',
#  'Cannabis Clinics',
#  'Escape Games',
#  'Dumplings',
#  'Guns & Ammo',
#  'Hungarian',
#  'Vape Shops',
#  'Tasting Classes',
#  'Farms',
#  'Nurseries & Gardening',
#  'Pick Your Own Farms',
#  'Eastern European',
#  'Candy Stores',
#  'Outlet Stores',
#  'Iberian',
#  'Bike Rentals',
#  'Bikes',
#  'Sporting Goods',
#  'Osteopaths',
#  'Medical Centers',
#  'Hospitals',
#  'Furniture Stores',
#  'Home Decor',
#  'Outdoor Furniture Stores',
#  'Drive-Thru Bars',
#  'Community Service/Non-Profit',
#  'Car Wash',
#  'Billing Services',
#  'Department Stores',
#  'Toy Stores',
#  'Guamanian',
#  'Mobile Phones',
#  'Discount Store',
#  'Pop-up Shops',
#  'Water Stores',
#  'Egyptian',
#  'Swimming Pools',
#  'Tennis',
#  "Men's Clothing",
#  'Axe Throwing',
#  'Georgian',
#  'Pool & Billiards',
#  'Trinidadian',
#  'Furniture Reupholstery',
#  'Leisure Centers',
#  'Laser Tag',
#  'Carpet Cleaning',
#  'Cambodian',
#  'Haitian',
#  'Shaved Snow',
#  'Pet Services',
#  'Rafting/Kayaking',
#  'Paddleboarding',
#  'Reiki',
#  'Medical Spas',
#  'Supernatural Readings',
#  'Home Cleaning',
#  'Thrift Stores',
#  'Vitamins & Supplements',
#  'Traditional Chinese Medicine',
#  'Coffee & Tea Supplies',
#  'Skin Care',
#  'Acupuncture',
#  'Weight Loss Centers',
#  'Counseling & Mental Health',
#  'Tuscan',
#  'Property Management',
#  'International',
#  'Golf Lessons',
#  'Photographers',
#  'Zoos',
#  'Graphic Design',
#  'Delicatessen',
#  'Newspapers & Magazines',
#  'Cabaret',
#  'Food Tours',
#  'Cosmetics & Beauty Supply',
#  'Videos & Video Game Rental',
#  'Indonesian',
#  'Israeli',
#  'Australian',
#  'Syrian',
#  'Amusement Parks',
#  'Team Building Activities',
#  'Nail Salons',
#  'Waxing',
#  'Hair Removal',
#  'Beer Tours',
#  'Auto Detailing',
#  'Senegalese',
#  'Public Markets',
#  'CSA',
#  'Educational Services',
#  'Recreation Centers',
#  'Trainers',
#  'Couriers & Delivery Services',
#  'Sardinian',
#  'Champagne Bars',
#  'Pediatricians',
#  'Churches',
#  'Hair Salons',
#  'Kids Hair Salons',
#  'Propane',
#  'Interior Design',
#  'Wine Tasting Classes',
#  'Internet Service Providers',
#  'Colleges & Universities',
#  'University Housing',
#  'Souvenir Shops',
#  'Lahmacun',
#  'Kitchen Incubators',
#  'Race Tracks',
#  'Stadiums & Arenas',
#  'Sports Clubs',
#  'Buddhist Temples',
#  'Parks',
#  'Aquariums',
#  'Speakeasies',
#  'Czech',
#  'Kombucha',
#  'Beer Hall',
#  'Tree Services',
#  'Roofing',
#  'Solar Installation',
#  'Dance Studios',
#  'Departments of Motor Vehicles',
#  'Funeral Services & Cemeteries',
#  'Musicians',
#  'Pharmacy',
#  'Eyelash Service',
#  'Wine Tours',
#  'Pet Adoption',
#  'Nutritionists',
#  'Antiques',
#  'Plastic Surgeons',
#  'Cosmetic Surgeons',
#  'Used Bookstore',
#  'Pest Control',
#  'Cards & Stationery',
#  'Supper Clubs',
#  'Parent Cafes',
#  'Comic Books',
#  'Ski Resorts',
#  'Reflexology',
#  'Music & DVDs',
#  'Personal Assistants',
#  'Vinyl Records',
#  'Virtual Reality Centers',
#  'Car Dealers',
#  'Auto Parts & Supplies',
#  'Auction Houses',
#  'Movers',
#  'Septic Services',
#  'Customized Merchandise',
#  'Screen Printing/T-Shirt Printing',
#  'Water Heater Installation/Repair',
#  'Water Purification Services',
#  'Batting Cages',
#  'Dietitians',
#  'Walking Tours',
#  'Homeowner Association',
#  'Mattresses',
#  'Food Banks',
#  'Fireplace Services',
#  'Adult Education',
#  'Boat Tours',
#  'Somali',
#  'Nail Technicians',
#  'Lawyers',
#  'Cultural Center',
#  'Golf Equipment',
#  'Hotel bar',
#  'Business Consulting',
#  'Barbers',
#  'Dentists',
#  'Oral Surgeons',
#  'Strip Clubs',
#  'Hunting & Fishing Supplies',
#  'Airport Lounges',
#  'Coffeeshops',
#  'Skating Rinks',
#  'Beach Bars',
#  'Veterinarians',
#  'Dog Parks',
#  'Sri Lankan',
#  'Recycling Center',
#  'Auto Glass Services',
#  'Auto Repair',
#  'Watches',
#  'Oil Change Stations',
#  'Laundry Services',
#  'Advertising',
#  'Chiropractors',
#  'Airports',
#  'Airport Terminals',
#  'Dance Schools',
#  'Dry Cleaning',
#  'Laundromat',
#  'Religious Items',
#  'Pet Sitting',
#  'Parking',
#  'Internal Medicine',
#  'Eyewear & Opticians',
#  'Vacation Rentals',
#  'Horseback Riding',
#  'LAN Centers',
#  'Auto Customization',
#  'Used Car Dealers',
#  'Home Theatre Installation',
#  'TV Mounting',
#  'Art Tours',
#  'Commercial Truck Repair',
#  'Service Stations',
#  'General Dentistry',
#  'RV Parks',
#  'Used',
#  'Vintage & Consignment',
#  'Health Retreats',
#  'Hiking',
#  'Soccer',
#  'Amateur Sports Teams',
#  'Tutoring Centers',
#  "Men's Hair Salons",
#  'Grill Services',
#  'Floral Designers',
#  'Oriental',
#  'Honey',
#  'Guest Houses',
#  'Transportation',
#  'Fireworks',
#  'Christmas Trees',
#  'Sports Betting',
#  'Marketing',
#  'Makeup Artists',
#  'Taxis',
#  'Public Transportation',
#  'Airport Shuttles',
#  'Train Stations',
#  'Roman',
#  'Outdoor Gear',
#  'Fire Departments',
#  'Go Karts',
#  'Fuzhou',
#  'Hair Loss Centers',
#  'Personal Injury Law',
#  'Business Law',
#  'Contract Law',
#  'Real Estate Law',
#  'Employment Law',
#  'Legal Services',
#  'Divorce & Family Law',
#  'General Litigation',
#  'Wheel & Rim Repair',
#  'Tires',
#  'Pressure Washers',
#  'Paint & Sip',
#  'Pet Groomers',
#  'Hair Stylists',
#  'Cabinetry',
#  'Tiling',
#  'Bridal',
#  'Head Shops',
#  'Trampoline Parks',
#  'Golf Cart Rentals',
#  'Real Estate Services',
#  'Garage Door Services',
#  'Keys & Locksmiths',
#  'Maternity Wear',
#  'Limos',
#  'Pawn Shops',
#  'Home Organization',
#  'Session Photography',
#  'Bike Repair/Maintenance',
#  'Ticket Sales',
#  'Country Dance Halls',
#  'Musical Instruments & Teachers',
#  'Office Cleaning',
#  'Damage Restoration',
#  'Conveyor Belt Sushi',
#  'Self Storage',
#  'Climbing',
#  'Threading Services',
#  'Eyebrow Services',
#  'Jails & Prisons',
#  'Art Classes',
#  'Hardware Stores',
#  'Junk Removal & Hauling',
#  'Haunted Houses',
#  'Video Game Stores',
#  'Wildlife Control',
#  'Flight Instruction',
#  'Cucina campana',
#  'Sports Wear',
#  'Car Stereo Installation',
#  'Trailer Repair',
#  'RV Repair',
#  'Smog Check Stations',
#  'Transmission Repair',
#  'Windshield Installation & Repair',
#  'Roadside Assistance',
#  'Battery Stores',
#  'Landscape Architects',
#  'Landscaping',
#  'Lawn Services',
#  'Gardeners',
#  'Irrigation',
#  'DJs',
#  'Music Production Services',
#  'Recording & Rehearsal Studios',
#  'Skate Shops',
#  'Pita',
#  'Drive-In Theater',
#  'Audio/Visual Equipment Rental',
#  'Community Centers',
#  'Hainan',
#  'Bocce Ball',
#  'Trivia Hosts',
#  'Botanical Gardens',
#  'Investing',
#  'Auto Loan Providers',
#  'Child Care & Day Care',
#  'Wedding Chapels',
#  'Tonkatsu',
#  'Donburi',
#  'Towing',
#  'Packing Services',
#  'Car Share Services',
#  'Costumes',
#  'Real Estate Agents',
#  'Boat Repair',
#  'Marinas',
#  'Animal Shelters',
#  'Shoe Stores',
#  'Radio Stations',
#  'Hostels',
#  'Perfume',
#  'Truck Rental',
#  'Commercial Truck Dealers',
#  'Airlines',
#  'Municipality',
#  'Gemstones & Minerals',
#  'Spiritual Shop',
#  'Private Tutors',
#  'Holiday Decorations',
#  'Psychiatrists',
#  'Neurologist',
#  'Family Practice',
#  'Visitor Centers',
#  'Elementary Schools',
#  'Ice Delivery',
#  'Clothing Rental',
#  'Trains',
#  'Pet Photography',
#  'Rolfing',
#  'Officiants',
#  'Ethical Grocery',
#  'Gymnastics',
#  'Pilates',
#  'Pet Boarding',
#  'Tax Services',
#  'Shipping Centers',
#  'Pet Training',
#  'Diagnostic Imaging',
#  'Diagnostic Services',
#  'Radiologists',
#  'Grilling Equipment',
#  'Rest Stops',
#  'Calabrian',
#  'Blow Dry/Out Services',
#  'Hair Extensions',
#  'Candle Stores',
#  'Financial Advising',
#  'Check Cashing/Pay-day Loans',
#  'Air Duct Cleaning',
#  'Horse Racing',
#  'Electronics Repair',
#  'Livestock Feed & Supply',
#  'Leather Goods']

# %%
def extract_relevant_category(categories):
    """
    Clasifica las categorías de negocios dentro de grupos jerárquicos relevantes.

    Args:
        categories (str): Lista de categorías separadas por comas.

    Returns:
        str: La categoría más relevante del negocio o 'Other' si no encaja en ninguna categoría relevante.
    """
    # Diccionario de grupos de categorías
    category_groups = {
        "Asian Cuisine": [
            "Japanese", "Chinese", "Korean", "Vietnamese", "Thai", "Taiwanese", "Sushi Bars", "Ramen", "Dim Sum",
            "Laotian", "Shanghainese", "Cantonese", "Szechuan", "Himalayan/Nepalese", "Pan Asian", "Hot Pot", "Teppanyaki"
        ],
        "European Cuisine": [
            "Italian", "French", "Spanish", "Greek", "Mediterranean", "Turkish", "German", "Portuguese", "Basque",
            "Belgian", "Austrian", "Sicilian", "Polish", "Ukrainian", "Russian", "Hungarian", "Scandinavian", "Modern European"
        ],
        "American Cuisine": [
            "American (New)", "American (Traditional)", "Southern", "Soul Food", "Diners", "Tex-Mex", "Barbeque",
            "Steakhouses", "Burgers", "Comfort Food", "Canadian (New)"
        ],
        "Latin Cuisine": [
            "Mexican", "Cuban", "Peruvian", "Argentine", "Colombian", "Brazilian", "Puerto Rican", "Honduran",
            "Dominican", "Latin American", "Empanadas", "New Mexican Cuisine"
        ],
        "Middle Eastern & African Cuisine": [
            "Middle Eastern", "Lebanese", "Persian/Iranian", "Ethiopian", "Moroccan", "African", "South African", "Kebab"
        ],
        "Beverages & Desserts": [
            "Coffee & Tea", "Bubble Tea", "Tea Rooms", "Ice Cream & Frozen Yogurt", "Gelato", "Cupcakes", "Donuts",
            "Cocktail Bars", "Beer Bar", "Wine Bars", "Tiki Bars", "Juice Bars & Smoothies", "Shaved Ice", "Waffles"
        ],
        "Fast Food & Chains": [
            "Fast Food", "Pizza", "Chicken Wings", "Hot Dogs", "Sandwiches", "Wraps", "Bagels", "Food Trucks",
            "Fish & Chips", "Tacos", "Pasta Shops", "Buffets"
        ],
        "Vegetarian & Specialty Diets": [
            "Vegetarian", "Vegan", "Gluten-Free", "Kosher", "Live/Raw Food", "Halal"
        ],
        "Other International Cuisine": [
            "Indian", "Pakistani", "Afghan", "Hawaiian", "Filipino", "Malaysian", "Indonesian", "Israeli",
            "Australian", "Syrian", "Brazilian", "Cambodian", "Haitian", "Vietnamese"
        ],
        "General Food & Services": [
            "Food", "Ethnic Food", "Specialty Food", "Imported Food", "Grocery", "Farmers Market", "Meat Shops",
            "Food Stands", "Cheese Shops", "Beverage Store", "Seafood Markets", "Do-It-Yourself Food", "Restaurant Supplies",
            "Catering", "Food Delivery Services"
        ],
        "Entertainment & Nightlife": [
            "Bars", "Nightlife", "Pubs", "Dive Bars", "Music Venues", "Dance Clubs", "Karaoke", "Comedy Clubs",
            "Speakeasies", "Wine Tasting Room", "Beer Gardens", "Lounges"
        ]
    }

    if not categories or not isinstance(categories, str):
        return 'Other'  # Retorna 'Other' si no hay categorías válidas

    # Dividir las categorías en una lista
    category_list = [cat.strip() for cat in categories.split(',')]

    # Buscar la categoría más relevante
    for main_group, subcategories in category_groups.items():
        for category in category_list:
            if category in subcategories:
                return main_group

    # Si no hay coincidencias, retornar 'Other'
    return 'Other'

# %%
restaurant_data['relevant_category'] = restaurant_data['categories'].apply(extract_relevant_category)

# %%
restaurant_data.head()
# Out:
#               business_id                  name              address  \
# 0  11HXgzo47w5e5pziFXpTNg  Market 16 Noodle Bar       34TH Market St
# 1  -_mCgBtlEGbzbTsjnuXm3Q  Little Caesars Pizza       5207 Walnut St
# 2  V41hJnfJSAad4L_YdVQBGQ                 Zen Q     10807 Jasper Ave
# 3  -m_fl--6j4DFv1RlOtuL1g  Sukhothai Restaurant  11525 104 Avenue NW
# 4  QYnfbwG2fDfuWAI6RbGz4g          Craft & Claw      126 Chestnut St
#
#            city state postal_code   latitude   longitude  stars  review_count  \
# 0  Philadelphia    PA       19104  39.955696  -75.191610    1.5            39
# 1  Philadelphia    PA       19139  39.957348  -75.225982    2.0             5
# 2      Edmonton    AB     T5J 5G9  53.540780 -113.507118    4.0            12
# 3      Edmonton    AB     T5K 2S2  53.545830 -113.520614    3.0            24
# 4  Philadelphia    PA       19106  39.948092  -75.143565    4.0            30
#
#    is_open                                         attributes  \
# 0        0  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 1        1  {'Ambience': "{'touristy': False, 'hipster': F...
# 2        1  {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
# 3        0  {'HasTV': 'False', 'RestaurantsReservations': ...
# 4        0  {'OutdoorSeating': 'False', 'GoodForKids': 'Fa...
#
#                                           categories  \
# 0  Food, Noodles, Specialty Food, Ethnic Food, Im...
# 1                                 Pizza, Restaurants
# 2  Desserts, Restaurants, Taiwanese, Bubble Tea, ...
# 3                                  Thai, Restaurants
# 4                               Seafood, Restaurants
#
#                                                hours   relevant_category
# 0  {'Monday': '10:0-20:0', 'Tuesday': '10:0-20:0'...       Asian Cuisine
# 1                                                NaN  Fast Food & Chains
# 2  {'Monday': '0:0-0:0', 'Tuesday': '11:0-22:0', ...       Asian Cuisine
# 3  {'Monday': '17:0-21:30', 'Tuesday': '17:0-21:3...       Asian Cuisine
# 4  {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...               Other

# %%
restaurant_data['relevant_category'].unique()
# Out:
# array(['Asian Cuisine', 'Fast Food & Chains', 'Other', 'American Cuisine',
#        'European Cuisine', 'General Food & Services', 'Latin Cuisine',
#        'Vegetarian & Specialty Diets', 'Beverages & Desserts',
#        'Entertainment & Nightlife', 'Middle Eastern & African Cuisine',
#        'Other International Cuisine'], dtype=object)

# %%
# Filtramos por los Other
restaurant_data_filtrado = restaurant_data[restaurant_data['relevant_category'] != 'Other']

restaurant_data_filtrado
# Out:
#                   business_id                                    name  \
# 0      11HXgzo47w5e5pziFXpTNg                    Market 16 Noodle Bar
# 1      -_mCgBtlEGbzbTsjnuXm3Q                    Little Caesars Pizza
# 2      V41hJnfJSAad4L_YdVQBGQ                                   Zen Q
# 3      -m_fl--6j4DFv1RlOtuL1g                    Sukhothai Restaurant
# 5      0RuvlgTnKFbX3IK0ZOOocA                         Green Eggs Café
# ...                       ...                                     ...
# 51758  mKKuShu5EQolhOeih90V4w  Brewsters Brewing Company & Restaurant
# 51759  -_oHNNTvb4gC1PXWHG8tVw                             Raceway Pub
# 51760  b36EeutJRvowZMr9TpQm0w                       Lighthouse Coffee
# 51761  __Jhyl5p8bfnnYOGjwPtsg                      Al-Sham Restaurant
# 51762  nwfUGLlKaF3D3OPS4idFtw                             Tim Hortons
#
#                         address          city state postal_code   latitude  \
# 0                34TH Market St  Philadelphia    PA       19104  39.955696
# 1                5207 Walnut St  Philadelphia    PA       19139  39.957348
# 2              10807 Jasper Ave      Edmonton    AB     T5J 5G9  53.540780
# 3           11525 104 Avenue NW      Edmonton    AB     T5K 2S2  53.545830
# 5                 212 S 13th St  Philadelphia    PA       19107  39.948123
# ...                         ...           ...   ...         ...        ...
# 51758      2335 111th Street NW      Edmonton    AB     T6J 5E5  53.454880
# 51759    9104 Crawfordsville Rd  Indianapolis    IN       46234  39.816325
# 51760  5255 Vista Blvd, Ste C-2        Sparks    NV       89436  39.586883
# 51761           201 W Boise Ave         Boise    ID       83706  43.585883
# 51762       10665 Jasper Avenue      Edmonton    AB     T5J 3S9  53.540603
#
#         longitude  stars  review_count  is_open  \
# 0      -75.191610    1.5            39        0
# 1      -75.225982    2.0             5        1
# 2     -113.507118    4.0            12        1
# 3     -113.520614    3.0            24        0
# 5      -75.162463    4.0          2679        1
# ...           ...    ...           ...      ...
# 51758 -113.515076    3.0            42        0
# 51759  -86.323270    3.5            17        1
# 51760 -119.716406    4.5           238        1
# 51761 -116.183792    4.0            19        0
# 51762 -113.504063    3.5            12        1
#
#                                               attributes  \
# 0      {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 1      {'Ambience': "{'touristy': False, 'hipster': F...
# 2      {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
# 3      {'HasTV': 'False', 'RestaurantsReservations': ...
# 5      {'BusinessParking': "{'garage': False, 'street...
# ...                                                  ...
# 51758  {'Caters': 'False', 'OutdoorSeating': 'True', ...
# 51759  {'RestaurantsDelivery': 'True', 'RestaurantsAt...
# 51760  {'WiFi': "u'free'", 'BusinessParking': "{'gara...
# 51761  {'RestaurantsPriceRange2': '1', 'HasTV': 'True...
# 51762  {'RestaurantsGoodForGroups': 'True', 'GoodForK...
#
#                                               categories  \
# 0      Food, Noodles, Specialty Food, Ethnic Food, Im...
# 1                                     Pizza, Restaurants
# 2      Desserts, Restaurants, Taiwanese, Bubble Tea, ...
# 3                                      Thai, Restaurants
# 5      Restaurants, American (New), Diners, Breakfast...
# ...                                                  ...
# 51758  Food, Nightlife, American (New), Bars, America...
# 51759  Nightlife, Pubs, Burgers, Bars, Restaurants, P...
# 51760  Food, Juice Bars & Smoothies, Restaurants, Cof...
# 51761                 Arabic, Mediterranean, Restaurants
# 51762  Bakeries, Food, Coffee & Tea, Restaurants, Don...
#
#                                                    hours     relevant_category
# 0      {'Monday': '10:0-20:0', 'Tuesday': '10:0-20:0'...         Asian Cuisine
# 1                                                    NaN    Fast Food & Chains
# 2      {'Monday': '0:0-0:0', 'Tuesday': '11:0-22:0', ...         Asian Cuisine
# 3      {'Monday': '17:0-21:30', 'Tuesday': '17:0-21:3...         Asian Cuisine
# 5      {'Monday': '9:0-15:0', 'Tuesday': '9:0-15:0', ...      American Cuisine
# ...                                                  ...                   ...
# 51758  {'Monday': '11:30-23:0', 'Tuesday': '11:30-0:0...      American Cuisine
# 51759  {'Monday': '9:0-3:0', 'Tuesday': '9:0-3:0', 'W...      American Cuisine
# 51760  {'Monday': '6:0-18:0', 'Tuesday': '6:0-18:0', ...  Beverages & Desserts
# 51761  {'Monday': '11:0-0:0', 'Tuesday': '11:0-0:0', ...      European Cuisine
# 51762                                                NaN  Beverages & Desserts
#
# [49880 rows x 15 columns]

# %% [markdown]
# Descargar la data de review de cada usuario he identificarlo por usuario

# %%
# Cargar el dataset filtrado
data_path = '/content/drive/MyDrive/IIC3633-2024-2/Restaurante/yelp_dataset/review_sample.csv'
#data_path = 'review_sample.csv'

review_data = pd.read_csv(data_path)

# Mostrar las primeras filas
print('Dataset cargado:')
review_data.head()
# Out:
# Dataset cargado:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 2  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 3  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# 4  JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg
#
#    stars  useful  funny  cool  \
# 0    3.0     0.0    0.0   0.0
# 1    3.0     0.0    0.0   0.0
# 2    5.0     1.0    0.0   1.0
# 3    4.0     1.0    0.0   1.0
# 4    1.0     1.0    2.0   1.0
#
#                                                 text                 date
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# 2  Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04 00:01:03
# 3  Cute interior and owner (?) gave us tour of up...  2017-01-14 20:54:15
# 4  I am a long term frequent customer of this est...  2015-09-23 23:10:31

# %%
# Unir las reseñas con los restaurantes filtrados usando business_id
data_restaurante_user = pd.merge(review_data, restaurant_data, on='business_id', how='inner')

# Mostrar una muestra de los datos combinados
data_restaurante_user.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 2  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 3  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# 4  JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg
#
#    stars_x  useful  funny  cool  \
# 0      3.0     0.0    0.0   0.0
# 1      3.0     0.0    0.0   0.0
# 2      5.0     1.0    0.0   1.0
# 3      4.0     1.0    0.0   1.0
# 4      1.0     1.0    2.0   1.0
#
#                                                 text                 date  \
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# 2  Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04 00:01:03
# 3  Cute interior and owner (?) gave us tour of up...  2017-01-14 20:54:15
# 4  I am a long term frequent customer of this est...  2015-09-23 23:10:31
#
#                            name  ... postal_code   latitude   longitude  \
# 0  Turning Point of North Wales  ...       19454  40.210196  -75.223639
# 1             Kettle Restaurant  ...       85713  32.207233 -110.980864
# 2                         Zaika  ...       19114  40.079848  -75.025080
# 3                          Melt  ...       70119  29.962102  -90.087958
# 4                      Dmitri's  ...       19147  39.938013  -75.148131
#
#   stars_y  review_count  is_open  \
# 0     3.0           169        1
# 1     3.5            47        1
# 2     4.0           181        1
# 3     4.0            32        0
# 4     4.0           273        0
#
#                                           attributes  \
# 0  {'NoiseLevel': "u'average'", 'HasTV': 'False',...
# 1  {'RestaurantsReservations': 'True', 'BusinessP...
# 2  {'Caters': 'True', 'Ambience': "{'romantic': F...
# 3  {'BusinessParking': "{'garage': False, 'street...
# 4  {'BusinessParking': "{'garage': False, 'street...
#
#                                           categories  \
# 0  Restaurants, Breakfast & Brunch, Food, Juice B...
# 1                    Restaurants, Breakfast & Brunch
# 2              Halal, Pakistani, Restaurants, Indian
# 3  Sandwiches, Beer, Wine & Spirits, Bars, Food, ...
# 4         Mediterranean, Restaurants, Seafood, Greek
#
#                                                hours  \
# 0  {'Monday': '7:30-15:0', 'Tuesday': '7:30-15:0'...
# 1                                                NaN
# 2  {'Tuesday': '11:0-21:0', 'Wednesday': '11:0-21...
# 3  {'Monday': '0:0-0:0', 'Friday': '11:0-17:0', '...
# 4  {'Wednesday': '17:30-21:0', 'Thursday': '17:30...
#
#               relevant_category
# 0              American Cuisine
# 1                         Other
# 2  Vegetarian & Specialty Diets
# 3              American Cuisine
# 4              European Cuisine
#
# [5 rows x 23 columns]

# %%
# Guardar los datos combinados en un archivo CSV
data_restaurante_user.to_csv('/content/drive/MyDrive/IIC3633-2024-2/Restaurante/yelp_dataset/data_restaurante_user.csv', index=False)

# %%
# Cargar el data_restaurante_user
data_path = '/content/drive/MyDrive/IIC3633-2024-2/Restaurante/yelp_dataset/data_restaurante_user.csv'

data_restaurante_user = pd.read_csv(data_path)

# %%
# Seleccionar columnas relevantes
data_restaurante_user = data_restaurante_user[['user_id', 'business_id', 'stars_x', 'text', 'date', 'name', 'categories', 'relevant_category']]

# Mostrar las primeras filas del nuevo DataFrame
data_restaurante_user.head()
# Out:
#                   user_id             business_id  stars_x  \
# 0  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw      3.0
# 1  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A      3.0
# 2  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA      5.0
# 3  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ      4.0
# 4  eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg      1.0
#
#                                                 text                 date  \
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# 2  Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04 00:01:03
# 3  Cute interior and owner (?) gave us tour of up...  2017-01-14 20:54:15
# 4  I am a long term frequent customer of this est...  2015-09-23 23:10:31
#
#                            name  \
# 0  Turning Point of North Wales
# 1             Kettle Restaurant
# 2                         Zaika
# 3                          Melt
# 4                      Dmitri's
#
#                                           categories  \
# 0  Restaurants, Breakfast & Brunch, Food, Juice B...
# 1                    Restaurants, Breakfast & Brunch
# 2              Halal, Pakistani, Restaurants, Indian
# 3  Sandwiches, Beer, Wine & Spirits, Bars, Food, ...
# 4         Mediterranean, Restaurants, Seafood, Greek
#
#               relevant_category
# 0              American Cuisine
# 1                         Other
# 2  Vegetarian & Specialty Diets
# 3              American Cuisine
# 4              European Cuisine

# %%
# Agrupar por usuario la tabla data_restaurante_user para tener el promedio stars
mean_stars_per_user = data_restaurante_user.groupby('user_id')['stars_x'].mean()

# Hacemos un round a la decima
mean_stars_per_user = mean_stars_per_user.round(1)

# Ahora agregamos la columna mean_stars a la tabla data_restaurante_user
data_restaurante_user['mean_stars'] = data_restaurante_user['user_id'].map(mean_stars_per_user)
data_restaurante_user
# Out:
#                         user_id             business_id  stars_x  \
# 0        mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw      3.0
# 1        8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A      3.0
# 2        _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA      5.0
# 3        bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ      4.0
# 4        eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg      1.0
# ...                         ...                     ...      ...
# 4675750  x1QLCwZGFAjxRRw4EHc3-g  1_BVWDzi5cVqWxNe9bOMMQ      5.0
# 4675751  7L7GL5Pi2cf8mbm2Dpw4zw  e_E-jq9mwm7wk75k7Yi-Xw      5.0
# 4675752  RKPkxOYQlM0BjhM-H6_vAw  X4mouE_cMiwbfyCPZ_K-FA      4.0
# 4675753  YwAMC-jvZ1fvEUum6QkEkw  Rr9kKArrMhSLVE9a53q-aA      5.0
# 4675754  6JehEvdoCvZPJ_XIxnzIIw  VAeEXLbEcI9Emt9KGYq9aA      3.0
#
#                                                       text  \
# 0        If you decide to eat here, just be aware it is...
# 1        Family diner. Had the buffet. Eclectic assortm...
# 2        Wow!  Yummy, different,  delicious.   Our favo...
# 3        Cute interior and owner (?) gave us tour of up...
# 4        I am a long term frequent customer of this est...
# ...                                                    ...
# 4675750  Don't misinterpret my 5-star review....I don't...
# 4675751  It is very rare for a restaurant to be this go...
# 4675752  Good, maybe very good.  I went for lunch, so t...
# 4675753  For when I'm feeling like ignoring my calorie-...
# 4675754  Located in the 'Walking District' in Nashville...
#
#                         date                          name  \
# 0        2018-07-07 22:09:11  Turning Point of North Wales
# 1        2014-02-05 20:30:30             Kettle Restaurant
# 2        2015-01-04 00:01:03                         Zaika
# 3        2017-01-14 20:54:15                          Melt
# 4        2015-09-23 23:10:31                      Dmitri's
# ...                      ...                           ...
# 4675750  2016-04-30 01:02:34                       Wendy's
# 4675751  2022-01-17 22:36:01                          Lark
# 4675752  2015-01-23 23:52:03                       Marhaba
# 4675753  2022-01-19 18:59:27             Sauce on the Side
# 4675754  2018-01-02 22:50:47                  The Pharmacy
#
#                                                 categories  \
# 0        Restaurants, Breakfast & Brunch, Food, Juice B...
# 1                          Restaurants, Breakfast & Brunch
# 2                    Halal, Pakistani, Restaurants, Indian
# 3        Sandwiches, Beer, Wine & Spirits, Bars, Food, ...
# 4               Mediterranean, Restaurants, Seafood, Greek
# ...                                                    ...
# 4675750              Restaurants, Burgers, Food, Fast Food
# 4675751  Bars, Restaurants, American (New), Beer Bar, N...
# 4675752  Halal, Lebanese, Mediterranean, Greek, Restaur...
# 4675753  Desserts, Pizza, Salad, Food, Beer, Wine & Spi...
# 4675754  Burgers, Sandwiches, Food, Beer, Wine & Spirit...
#
#                     relevant_category  mean_stars
# 0                    American Cuisine         4.0
# 1                               Other         4.3
# 2        Vegetarian & Specialty Diets         4.8
# 3                    American Cuisine         3.0
# 4                    European Cuisine         1.0
# ...                               ...         ...
# 4675750              American Cuisine         4.1
# 4675751              American Cuisine         3.2
# 4675752              European Cuisine         4.1
# 4675753              European Cuisine         4.3
# 4675754              American Cuisine         3.5
#
# [4675755 rows x 9 columns]

# %%
# Filtramos por todos los stars_x que sean mayor o igual a mean_stars
data_restaurante_user_filtrado = data_restaurante_user[data_restaurante_user['stars_x'] >= data_restaurante_user['mean_stars']]
data_restaurante_user_filtrado
# Out:
#                         user_id             business_id  stars_x  \
# 2        _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA      5.0
# 3        bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ      4.0
# 4        eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg      1.0
# 5        yfFzsLmaWF2d4Sr0UNbBgg  LHSTtnW3YHCeUkRDGyJOyw      5.0
# 8        9OAtfnWag-ajVxRbUTGIyg  lj-E32x9_FA7GmUrBGBEWg      4.0
# ...                         ...                     ...      ...
# 4675743  LHWtjTG7e1NzNPYUbUo-9w  rgeuy1qbw6Z8B6CSVANHIA      5.0
# 4675745  QYZM8lgZn2HL_OWYAn7E1A  nrXtCSdfWg0TJ86onEZWkg      4.0
# 4675750  x1QLCwZGFAjxRRw4EHc3-g  1_BVWDzi5cVqWxNe9bOMMQ      5.0
# 4675751  7L7GL5Pi2cf8mbm2Dpw4zw  e_E-jq9mwm7wk75k7Yi-Xw      5.0
# 4675753  YwAMC-jvZ1fvEUum6QkEkw  Rr9kKArrMhSLVE9a53q-aA      5.0
#
#                                                       text  \
# 2        Wow!  Yummy, different,  delicious.   Our favo...
# 3        Cute interior and owner (?) gave us tour of up...
# 4        I am a long term frequent customer of this est...
# 5        Amazingly amazing wings and homemade bleu chee...
# 8        Love going here for happy hour or dinner!  Gre...
# ...                                                    ...
# 4675743  I've been to the other Federal Donuts location...
# 4675745  Took a colleague here for dinner as we were tr...
# 4675750  Don't misinterpret my 5-star review....I don't...
# 4675751  It is very rare for a restaurant to be this go...
# 4675753  For when I'm feeling like ignoring my calorie-...
#
#                         date                 name  \
# 2        2015-01-04 00:01:03                Zaika
# 3        2017-01-14 20:54:15                 Melt
# 4        2015-09-23 23:10:31             Dmitri's
# 5        2015-08-07 02:29:16      Fries Rebellion
# 8        2014-06-27 22:44:01  Brio Italian Grille
# ...                      ...                  ...
# 4675743  2012-10-13 14:39:37       Federal Donuts
# 4675745  2018-02-13 19:50:01   The Company Burger
# 4675750  2016-04-30 01:02:34              Wendy's
# 4675751  2022-01-17 22:36:01                 Lark
# 4675753  2022-01-19 18:59:27    Sauce on the Side
#
#                                                 categories  \
# 2                    Halal, Pakistani, Restaurants, Indian
# 3        Sandwiches, Beer, Wine & Spirits, Bars, Food, ...
# 4               Mediterranean, Restaurants, Seafood, Greek
# 5        Beer Bar, Bars, American (New), Gastropubs, Re...
# 8        Bars, Pizza, Nightlife, Cocktail Bars, Italian...
# ...                                                    ...
# 4675743  Donuts, Sandwiches, Soul Food, Food, Coffee & ...
# 4675745       Burgers, Restaurants, American (Traditional)
# 4675750              Restaurants, Burgers, Food, Fast Food
# 4675751  Bars, Restaurants, American (New), Beer Bar, N...
# 4675753  Desserts, Pizza, Salad, Food, Beer, Wine & Spi...
#
#                     relevant_category  mean_stars
# 2        Vegetarian & Specialty Diets         4.8
# 3                    American Cuisine         3.0
# 4                    European Cuisine         1.0
# 5                    American Cuisine         5.0
# 8                    European Cuisine         4.0
# ...                               ...         ...
# 4675743              American Cuisine         4.0
# 4675745              American Cuisine         4.0
# 4675750              American Cuisine         4.1
# 4675751              American Cuisine         3.2
# 4675753              European Cuisine         4.3
#
# [3252880 rows x 9 columns]

# %%
# Ver cuantas categorias tiene el usario ---2PmXbF47D870stH1jqA distintas
data_restaurante_user_filtrado[data_restaurante_user_filtrado['user_id'] == '---2PmXbF47D870stH1jqA']['relevant_category'].unique()
# Out:
# array(['American Cuisine', 'Latin Cuisine', 'European Cuisine'],
#       dtype=object)

# %%
# Configurar el valor de k
k = 3

# Seleccionar las columnas necesarias
user_category_df = data_restaurante_user_filtrado[['user_id', 'relevant_category']]

# Calcular las k categorías más visitadas por cada usuario
top_3_categories = (
    user_category_df.groupby(['user_id', 'relevant_category'])
    .size()  # Contar ocurrencias de cada categoría por usuario
    .reset_index(name='count')  # Resetear índice y nombrar la columna de conteo
    .sort_values(['user_id', 'count'], ascending=[True, False])  # Ordenar por usuario y conteo
    .groupby('user_id')  # Agrupar por usuario
    .head(k)  # Tomar las k categorías más vistas por usuario
)

# Mostrar los resultados
print(f'Top {k} categorías más visitadas por usuario:')
top_3_categories
# Out:
# Top 3 categorías más visitadas por usuario:
#                         user_id   relevant_category  count
# 0        ---2PmXbF47D870stH1jqA    American Cuisine     15
# 1        ---2PmXbF47D870stH1jqA    European Cuisine      6
# 2        ---2PmXbF47D870stH1jqA       Latin Cuisine      1
# 3        ---UgP94gokyCDuB5zUssA    American Cuisine      2
# 5        ---UgP94gokyCDuB5zUssA    European Cuisine      2
# ...                         ...                 ...    ...
# 2133650  zzz-M4QvkEpUWWPL9RTzLA    European Cuisine      1
# 2133651  zzzCg-_lpyYE82TlJCdwdw  Fast Food & Chains      1
# 2133652  zzzGgfvrSJ4AQeKtcgocIw    European Cuisine      1
# 2133653  zzzMBVS73g3ZJ7qL8JyhiA    American Cuisine      1
# 2133654  zzzUFM4HFe0SFG0bPjntQA    European Cuisine      1
#
# [1955659 rows x 3 columns]

# %%
# Configurar el valor de k
k = 5

# Seleccionar las columnas necesarias
user_category_df = data_restaurante_user_filtrado[['user_id', 'relevant_category']]

# Calcular las k categorías más visitadas por cada usuario
top_5_categories = (
    user_category_df.groupby(['user_id', 'relevant_category'])
    .size()  # Contar ocurrencias de cada categoría por usuario
    .reset_index(name='count')  # Resetear índice y nombrar la columna de conteo
    .sort_values(['user_id', 'count'], ascending=[True, False])  # Ordenar por usuario y conteo
    .groupby('user_id')  # Agrupar por usuario
    .head(k)  # Tomar las k categorías más vistas por usuario
)

# Mostrar los resultados
print(f'Top {k} categorías más visitadas por usuario:')
top_5_categories
# Out:
# Top 5 categorías más visitadas por usuario:
#                         user_id   relevant_category  count
# 0        ---2PmXbF47D870stH1jqA    American Cuisine     15
# 1        ---2PmXbF47D870stH1jqA    European Cuisine      6
# 2        ---2PmXbF47D870stH1jqA       Latin Cuisine      1
# 3        ---UgP94gokyCDuB5zUssA    American Cuisine      2
# 5        ---UgP94gokyCDuB5zUssA    European Cuisine      2
# ...                         ...                 ...    ...
# 2133650  zzz-M4QvkEpUWWPL9RTzLA    European Cuisine      1
# 2133651  zzzCg-_lpyYE82TlJCdwdw  Fast Food & Chains      1
# 2133652  zzzGgfvrSJ4AQeKtcgocIw    European Cuisine      1
# 2133653  zzzMBVS73g3ZJ7qL8JyhiA    American Cuisine      1
# 2133654  zzzUFM4HFe0SFG0bPjntQA    European Cuisine      1
#
# [2081809 rows x 3 columns]

# %%
# Configurar el valor de k
k = 7

# Seleccionar las columnas necesarias
user_category_df = data_restaurante_user_filtrado[['user_id', 'relevant_category']]

# Calcular las k categorías más visitadas por cada usuario
top_7_categories = (
    user_category_df.groupby(['user_id', 'relevant_category'])
    .size()  # Contar ocurrencias de cada categoría por usuario
    .reset_index(name='count')  # Resetear índice y nombrar la columna de conteo
    .sort_values(['user_id', 'count'], ascending=[True, False])  # Ordenar por usuario y conteo
    .groupby('user_id')  # Agrupar por usuario
    .head(k)  # Tomar las k categorías más vistas por usuario
)

# Mostrar los resultados
print(f'Top {k} categorías más visitadas por usuario:')
top_7_categories
# Out:
# Top 7 categorías más visitadas por usuario:
#                         user_id   relevant_category  count
# 0        ---2PmXbF47D870stH1jqA    American Cuisine     15
# 1        ---2PmXbF47D870stH1jqA    European Cuisine      6
# 2        ---2PmXbF47D870stH1jqA       Latin Cuisine      1
# 3        ---UgP94gokyCDuB5zUssA    American Cuisine      2
# 5        ---UgP94gokyCDuB5zUssA    European Cuisine      2
# ...                         ...                 ...    ...
# 2133650  zzz-M4QvkEpUWWPL9RTzLA    European Cuisine      1
# 2133651  zzzCg-_lpyYE82TlJCdwdw  Fast Food & Chains      1
# 2133652  zzzGgfvrSJ4AQeKtcgocIw    European Cuisine      1
# 2133653  zzzMBVS73g3ZJ7qL8JyhiA    American Cuisine      1
# 2133654  zzzUFM4HFe0SFG0bPjntQA    European Cuisine      1
#
# [2120103 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# Lista de DataFrames y valores de K para iterar
top_k_dfs = [top_3_categories, top_5_categories, top_7_categories]
k_values = [3, 5, 7]

# Crear la figura y los ejes para la grilla de gráficos (2 filas, 3 columnas)
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

for i, (top_k_df, k) in enumerate(zip(top_k_dfs, k_values)):
    # Gráfico 1: Cantidad de usuarios que tienen cada género en su top K
    genre_user_count = top_k_df['relevant_category'].value_counts()
    axes[0, i].bar(genre_user_count.index, genre_user_count.values, color='skyblue')
    axes[0, i].set_title(f"Cantidad de Usuarios con Cada Género en su Top {k}")
    axes[0, i].set_xlabel("Género")
    axes[0, i].set_ylabel("Cantidad de Usuarios")
    axes[0, i].tick_params(axis='x', rotation=90)

    # Agrupar por genero principal para saber la cantidad de peliculas tiene el top k
    group_movie_by_genre = top_k_df.groupby('relevant_category')['count'].sum()
    # Ordenar por values
    group_movie_by_genre = group_movie_by_genre.sort_values(ascending=False)

    # Gráfico 2: Cantidad de peliculas por género en usuarios del top K
    axes[1, i].bar(group_movie_by_genre.index, group_movie_by_genre.values, color='salmon')
    axes[1, i].set_title(f"Cantidad de Peliculas por Género en Usuarios del Top {k}")
    axes[1, i].set_xlabel("Género")
    axes[1, i].set_ylabel("Cantidad de Peliculas")
    axes[1, i].tick_params(axis='x', rotation=90)

# Ajustar el layout para mejor visualización
plt.tight_layout()
plt.show()

# %% [markdown]
# La cantidad de generos no se modifica orque usualmente por usuario se recomiendan un maximo de 3 categorias
