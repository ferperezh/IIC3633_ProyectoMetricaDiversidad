# %% [markdown]
# <a href="https://colab.research.google.com/github/ferperezh/IIC3633_ProyectoMetricaDiversidad/blob/main/procesamiento_pelicula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Procesamiento de data de Pelicula
#
# Primero creamos una instancia para descargar los archivos de pelicula de kaggle. Pero primero debes subir al colab el archivo `kaggle.json` con el usuario y permisos del kaggle.

# %%
# Crear el directorio .kaggle en Colab
# !mkdir -p ~/.kaggle

# Mover el archivo kaggle.json al directorio .kaggle
# !cp kaggle.json ~/.kaggle/

# Cambiar los permisos del archivo kaggle.json para asegurar privacidad
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# Instalamos la libreria kaggle para poder usarla

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.8.30)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.6)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.2.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.10)

# %% [markdown]
# Primero descargamos el dataset de [kaggle_movielens](https://www.kaggle.com/datasets/grouplens/movielens-20m-dataset?select=rating.csv). Para tener más información de la cancion.

# %%
# Descargar el dataset
# !kaggle datasets download -d grouplens/movielens-20m-dataset

# Descomprimir el archivo zip descargado
import zipfile
with zipfile.ZipFile("movielens-20m-dataset.zip", 'r') as zip_ref:
    zip_ref.extractall("movielens-20m-dataset")

print("Path to dataset files: movielens-20m-dataset")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/grouplens/movielens-20m-dataset
# License(s): unknown
# movielens-20m-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)
# Path to dataset files: movielens-20m-dataset

# %%
# Verificar archivos en el directorio
# !ls movielens-20m-dataset
# Out:
# genome_scores.csv  genome_tags.csv  link.csv  movie.csv  rating.csv  tag.csv

# %% [markdown]
# Ahora se carga los archivos .csv para poder unirlos y tener la información sobre cada canción para poder hacer la categorización de las canciones.

# %%
import pandas as pd

genome_scores = pd.read_csv('movielens-20m-dataset/genome_scores.csv')
genome_tags = pd.read_csv('movielens-20m-dataset/genome_tags.csv')
links = pd.read_csv('movielens-20m-dataset/link.csv')
movies = pd.read_csv('movielens-20m-dataset/movie.csv')
ratings = pd.read_csv('movielens-20m-dataset/rating.csv')
tags = pd.read_csv('movielens-20m-dataset/tag.csv')

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
ratings['userId'].nunique()
# Out:
# 138493

# %%
ratings.describe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00

# %% [markdown]
# Vemos que el promedio general dado a las peliculas es de 3.5 por lo que mayo a 3.5 de forma general seria las peliculas que consideramos parte del usuario. Pero para mas especificidad veremos el promedio por cada usuario y es ese el limite para distinguir las peliculas "elegidas por el usuario"

# %%
# Agrupar por usuario la tabla raitings para tener el rating promedio que le da a las peliculas
ratings_por_usuario = ratings.groupby('userId')['rating'].mean()
# Hacemos un round a la decima
ratings_por_usuario = ratings_por_usuario.round(1)
ratings_por_usuario

# Ahora agregamos la columna rating_mean a la tabla rating con esta informacion
ratings['rating_mean'] = ratings['userId'].map(ratings_por_usuario)
ratings
# Out:
#           userId  movieId  rating            timestamp  rating_mean
# 0              1        2     3.5  2005-04-02 23:53:47          3.7
# 1              1       29     3.5  2005-04-02 23:31:16          3.7
# 2              1       32     3.5  2005-04-02 23:33:39          3.7
# 3              1       47     3.5  2005-04-02 23:32:07          3.7
# 4              1       50     3.5  2005-04-02 23:29:40          3.7
# ...          ...      ...     ...                  ...          ...
# 20000258  138493    68954     4.5  2009-11-13 15:42:00          4.2
# 20000259  138493    69526     4.5  2009-12-03 18:31:48          4.2
# 20000260  138493    69644     3.0  2009-12-07 18:10:57          4.2
# 20000261  138493    70286     5.0  2009-11-13 15:42:24          4.2
# 20000262  138493    71619     2.5  2009-10-17 20:25:36          4.2
#
# [20000263 rows x 5 columns]

# %%
# Filtramos por todos los ratings que son mayor o igual al rating_mean
ratings_filtrados = ratings[ratings['rating'] >= ratings['rating_mean']]
ratings_filtrados
# Out:
#           userId  movieId  rating            timestamp  rating_mean
# 6              1      151     4.0  2004-09-10 03:08:54          3.7
# 7              1      223     4.0  2005-04-02 23:46:13          3.7
# 8              1      253     4.0  2005-04-02 23:35:40          3.7
# 9              1      260     4.0  2005-04-02 23:33:46          3.7
# 10             1      293     4.0  2005-04-02 23:31:43          3.7
# ...          ...      ...     ...                  ...          ...
# 20000256  138493    66762     4.5  2009-10-17 18:50:08          4.2
# 20000257  138493    68319     4.5  2009-12-07 18:15:20          4.2
# 20000258  138493    68954     4.5  2009-11-13 15:42:00          4.2
# 20000259  138493    69526     4.5  2009-12-03 18:31:48          4.2
# 20000261  138493    70286     5.0  2009-11-13 15:42:24          4.2
#
# [11276529 rows x 5 columns]

# %% [markdown]
# Ahora con estas peliculas las establecemos como las seleccionadas por el usuario las conectamos con la infromacion de la pelicula para tener los generos

# %%
#Merge de ratings filtrados con movies
movies_data = pd.merge(ratings_filtrados, movies, on='movieId', how='inner')
movies_data
# Out:
#           userId  movieId  rating            timestamp  rating_mean  \
# 0              1      151     4.0  2004-09-10 03:08:54          3.7
# 1              1      223     4.0  2005-04-02 23:46:13          3.7
# 2              1      253     4.0  2005-04-02 23:35:40          3.7
# 3              1      260     4.0  2005-04-02 23:33:46          3.7
# 4              1      293     4.0  2005-04-02 23:31:43          3.7
# ...          ...      ...     ...                  ...          ...
# 11276524  138493    66762     4.5  2009-10-17 18:50:08          4.2
# 11276525  138493    68319     4.5  2009-12-07 18:15:20          4.2
# 11276526  138493    68954     4.5  2009-11-13 15:42:00          4.2
# 11276527  138493    69526     4.5  2009-12-03 18:31:48          4.2
# 11276528  138493    70286     5.0  2009-11-13 15:42:24          4.2
#
#                                                       title  \
# 0                                            Rob Roy (1995)
# 1                                             Clerks (1994)
# 2         Interview with the Vampire: The Vampire Chroni...
# 3                 Star Wars: Episode IV - A New Hope (1977)
# 4         Léon: The Professional (a.k.a. The Professiona...
# ...                                                     ...
# 11276524                                       Paris (2008)
# 11276525                    X-Men Origins: Wolverine (2009)
# 11276526                                          Up (2009)
# 11276527         Transformers: Revenge of the Fallen (2009)
# 11276528                                  District 9 (2009)
#
#                                       genres
# 0                   Action|Drama|Romance|War
# 1                                     Comedy
# 2                               Drama|Horror
# 3                    Action|Adventure|Sci-Fi
# 4                Action|Crime|Drama|Thriller
# ...                                      ...
# 11276524                Comedy|Drama|Romance
# 11276525              Action|Sci-Fi|Thriller
# 11276526  Adventure|Animation|Children|Drama
# 11276527        Action|Adventure|Sci-Fi|IMAX
# 11276528             Mystery|Sci-Fi|Thriller
#
# [11276529 rows x 7 columns]

# %% [markdown]
# Vemos que por pelicula tenemos varios generos separados por | . Pero para propositos de hacer un analisis más general dejaremos el primer genero nomas

# %%
# Creamos la columna genero principal que es el primero genero que aparece en genres al se dividido por |
movies_data['genre_principal'] = movies_data['genres'].str.split('|').str[0]
movies_data
# Out:
#           userId  movieId  rating            timestamp  rating_mean  \
# 0              1      151     4.0  2004-09-10 03:08:54          3.7
# 1              1      223     4.0  2005-04-02 23:46:13          3.7
# 2              1      253     4.0  2005-04-02 23:35:40          3.7
# 3              1      260     4.0  2005-04-02 23:33:46          3.7
# 4              1      293     4.0  2005-04-02 23:31:43          3.7
# ...          ...      ...     ...                  ...          ...
# 11276524  138493    66762     4.5  2009-10-17 18:50:08          4.2
# 11276525  138493    68319     4.5  2009-12-07 18:15:20          4.2
# 11276526  138493    68954     4.5  2009-11-13 15:42:00          4.2
# 11276527  138493    69526     4.5  2009-12-03 18:31:48          4.2
# 11276528  138493    70286     5.0  2009-11-13 15:42:24          4.2
#
#                                                       title  \
# 0                                            Rob Roy (1995)
# 1                                             Clerks (1994)
# 2         Interview with the Vampire: The Vampire Chroni...
# 3                 Star Wars: Episode IV - A New Hope (1977)
# 4         Léon: The Professional (a.k.a. The Professiona...
# ...                                                     ...
# 11276524                                       Paris (2008)
# 11276525                    X-Men Origins: Wolverine (2009)
# 11276526                                          Up (2009)
# 11276527         Transformers: Revenge of the Fallen (2009)
# 11276528                                  District 9 (2009)
#
#                                       genres genre_principal
# 0                   Action|Drama|Romance|War          Action
# 1                                     Comedy          Comedy
# 2                               Drama|Horror           Drama
# 3                    Action|Adventure|Sci-Fi          Action
# 4                Action|Crime|Drama|Thriller          Action
# ...                                      ...             ...
# 11276524                Comedy|Drama|Romance          Comedy
# 11276525              Action|Sci-Fi|Thriller          Action
# 11276526  Adventure|Animation|Children|Drama       Adventure
# 11276527        Action|Adventure|Sci-Fi|IMAX          Action
# 11276528             Mystery|Sci-Fi|Thriller         Mystery
#
# [11276529 rows x 8 columns]

# %%
k = 3

user_genre_df = movies_data[['userId', 'genre_principal']]

# Calcular las k categorías más vistas por cada usuario
top_k_3_categories = (
    user_genre_df.groupby(['userId', 'genre_principal'])
    .size()  # Contar ocurrencias de cada género por usuario
    .reset_index(name='count')  # Resetear índice y nombrar la columna de conteo
    .sort_values(['userId', 'count'], ascending=[True, False])  # Ordenar por usuario y luego por conteo descendente
    .groupby('userId')  # Agrupar por usuario para obtener los top-k
    .head(k)  # Tomar los K géneros más escuchados por usuario
)

# Mostrar los resultados
print("Top k = 3 géneros más escuchados por usuario:")
top_k_3_categories
# Out:
# Top k = 3 géneros más escuchados por usuario:
#          userId genre_principal  count
# 0             1          Action     35
# 1             1       Adventure     22
# 4             1          Comedy     11
# 10            2          Action     19
# 13            2           Drama      8
# ...         ...             ...    ...
# 1070511  138492          Action     10
# 1070515  138492     Documentary      5
# 1070517  138493          Action     54
# 1070524  138493           Drama     46
# 1070521  138493          Comedy     40
#
# [414844 rows x 3 columns]

# %%
k = 5

user_genre_df = movies_data[['userId', 'genre_principal']]

# Calcular las k categorías más vistas por cada usuario
top_k_5_categories = (
    user_genre_df.groupby(['userId', 'genre_principal'])
    .size()  # Contar ocurrencias de cada género por usuario
    .reset_index(name='count')
    .sort_values(['userId', 'count'], ascending=[True, False])
    .groupby('userId')
    .head(k)
)

# Mostrar los resultados
print("Top k = 5 géneros más escuchados por usuario:")
top_k_5_categories
# Out:
# Top k = 5 géneros más escuchados por usuario:
#          userId genre_principal  count
# 0             1          Action     35
# 1             1       Adventure     22
# 4             1          Comedy     11
# 6             1           Drama      8
# 5             1           Crime      3
# ...         ...             ...    ...
# 1070517  138493          Action     54
# 1070524  138493           Drama     46
# 1070521  138493          Comedy     40
# 1070518  138493       Adventure     29
# 1070522  138493           Crime      9
#
# [675408 rows x 3 columns]

# %%
k = 7

user_genre_df = movies_data[['userId', 'genre_principal']]

# Calcular las k categorías más vistas por cada usuario
top_k_7_categories = (
    user_genre_df.groupby(['userId', 'genre_principal'])
    .size()
    .reset_index(name='count')
    .sort_values(['userId', 'count'], ascending=[True, False])
    .groupby('userId')
    .head(k)
)

# Mostrar los resultados
print("Top k = 7 géneros más escuchados por usuario:")
top_k_7_categories
# Out:
# Top k = 7 géneros más escuchados por usuario:
#          userId genre_principal  count
# 0             1          Action     35
# 1             1       Adventure     22
# 4             1          Comedy     11
# 6             1           Drama      8
# 5             1           Crime      3
# ...         ...             ...    ...
# 1070521  138493          Comedy     40
# 1070518  138493       Adventure     29
# 1070522  138493           Crime      9
# 1070525  138493          Horror      6
# 1070519  138493       Animation      5
#
# [869638 rows x 3 columns]

# %%
# Agrupar por genre_principal sumando los numeros de la columna count
top_k_3_categories_count = top_k_3_categories.groupby('genre_principal')['count'].sum()
top_k_3_categories_count
# Out:
# genre_principal
# (no genres listed)          4
# Action                2828348
# Adventure              422268
# Animation               17495
# Children                 7581
# Comedy                2578698
# Crime                  280122
# Documentary              8556
# Drama                 2204787
# Fantasy                    32
# Film-Noir                 174
# Horror                  26686
# Musical                    98
# Mystery                   728
# Romance                    22
# Sci-Fi                     53
# Thriller                  239
# War                         5
# Western                   126
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Lista de DataFrames y valores de K para iterar
top_k_dfs = [top_k_3_categories, top_k_5_categories, top_k_7_categories]
k_values = [3, 5, 7]

# Crear la figura y los ejes para la grilla de gráficos (2 filas, 3 columnas)
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

for i, (top_k_df, k) in enumerate(zip(top_k_dfs, k_values)):
    # Gráfico 1: Cantidad de usuarios que tienen cada género en su top K
    genre_user_count = top_k_df['genre_principal'].value_counts()
    axes[0, i].bar(genre_user_count.index, genre_user_count.values, color='skyblue')
    axes[0, i].set_title(f"Cantidad de Usuarios con Cada Género en su Top {k}")
    axes[0, i].set_xlabel("Género")
    axes[0, i].set_ylabel("Cantidad de Usuarios")
    axes[0, i].tick_params(axis='x', rotation=90)

    # Agrupar por genero principal para saber la cantidad de peliculas tiene el top k
    group_movie_by_genre = top_k_df.groupby('genre_principal')['count'].sum()
    # Ordenar por values
    group_movie_by_genre = group_movie_by_genre.sort_values(ascending=False)

    # Gráfico 2: Cantidad de peliculas por género en usuarios del top K
    axes[1, i].bar(group_movie_by_genre.index, group_movie_by_genre.values, color='salmon')
    axes[1, i].set_title(f"Cantidad de Peliculas por Género en Usuarios del Top {k}")
    axes[1, i].set_xlabel("Género")
    axes[1, i].set_ylabel("Cantidad de Peliculas")
    axes[1, i].tick_params(axis='x', rotation=90)

# Ajustar el layout para mejor visualización
plt.tight_layout()
plt.show()

# %% [markdown]
# vemos que la cantidad de generos no se aumenta o disminuye significativamente segun cambiemos el k. por lo que intentaremos ahora no solo con un genero principal sino incorporar los otros generos.
#
# Donde se concideren todos lo generos y no solo el primero.

# %%
movies_data['genre_list'] = movies_data['genres'].str.split('|')
movies_data
# Out:
#           userId  movieId  rating            timestamp  rating_mean  \
# 0              1      151     4.0  2004-09-10 03:08:54          3.7
# 1              1      223     4.0  2005-04-02 23:46:13          3.7
# 2              1      253     4.0  2005-04-02 23:35:40          3.7
# 3              1      260     4.0  2005-04-02 23:33:46          3.7
# 4              1      293     4.0  2005-04-02 23:31:43          3.7
# ...          ...      ...     ...                  ...          ...
# 11276524  138493    66762     4.5  2009-10-17 18:50:08          4.2
# 11276525  138493    68319     4.5  2009-12-07 18:15:20          4.2
# 11276526  138493    68954     4.5  2009-11-13 15:42:00          4.2
# 11276527  138493    69526     4.5  2009-12-03 18:31:48          4.2
# 11276528  138493    70286     5.0  2009-11-13 15:42:24          4.2
#
#                                                       title  \
# 0                                            Rob Roy (1995)
# 1                                             Clerks (1994)
# 2         Interview with the Vampire: The Vampire Chroni...
# 3                 Star Wars: Episode IV - A New Hope (1977)
# 4         Léon: The Professional (a.k.a. The Professiona...
# ...                                                     ...
# 11276524                                       Paris (2008)
# 11276525                    X-Men Origins: Wolverine (2009)
# 11276526                                          Up (2009)
# 11276527         Transformers: Revenge of the Fallen (2009)
# 11276528                                  District 9 (2009)
#
#                                       genres genre_principal  \
# 0                   Action|Drama|Romance|War          Action
# 1                                     Comedy          Comedy
# 2                               Drama|Horror           Drama
# 3                    Action|Adventure|Sci-Fi          Action
# 4                Action|Crime|Drama|Thriller          Action
# ...                                      ...             ...
# 11276524                Comedy|Drama|Romance          Comedy
# 11276525              Action|Sci-Fi|Thriller          Action
# 11276526  Adventure|Animation|Children|Drama       Adventure
# 11276527        Action|Adventure|Sci-Fi|IMAX          Action
# 11276528             Mystery|Sci-Fi|Thriller         Mystery
#
#                                        genre_list
# 0                   [Action, Drama, Romance, War]
# 1                                        [Comedy]
# 2                                 [Drama, Horror]
# 3                     [Action, Adventure, Sci-Fi]
# 4                [Action, Crime, Drama, Thriller]
# ...                                           ...
# 11276524                 [Comedy, Drama, Romance]
# 11276525               [Action, Sci-Fi, Thriller]
# 11276526  [Adventure, Animation, Children, Drama]
# 11276527        [Action, Adventure, Sci-Fi, IMAX]
# 11276528              [Mystery, Sci-Fi, Thriller]
#
# [11276529 rows x 9 columns]

# %%
# Crear un diccionario para contar los géneros de cada usuario
user_genre_counts = {}

for index, row in movies_data.iterrows():
    user_id = row['userId']
    genres = row['genre_list']

    if user_id not in user_genre_counts:
        user_genre_counts[user_id] = {}

    for genre in genres:
      if genre not in user_genre_counts[user_id]:
          user_genre_counts[user_id][genre] =  0
      user_genre_counts[user_id][genre] += 1

user_genre_counts
# Out:
# {1: {'Action': 35,
#   'Drama': 21,
#   'Romance': 10,
#   'War': 3,
#   'Comedy': 21,
#   'Horror': 22,
#   'Adventure': 42,
#   'Sci-Fi': 18,
#   'Crime': 12,
#   'Thriller': 23,
#   'Children': 6,
#   'Fantasy': 39,
#   'Western': 1,
#   'Musical': 1,
#   'Animation': 4,
#   'Mystery': 4,
#   'IMAX': 2},
#  2: {'Comedy': 6,
#   'Romance': 4,
#   'Drama': 12,
#   'Action': 19,
#   'Horror': 10,
#   'Thriller': 16,
#   'War': 4,
#   'Adventure': 17,
#   'Sci-Fi': 22,
#   'Western': 2,
#   'Mystery': 4,
#   'Crime': 1,
#   'Film-Noir': 1},
#  3: {'Crime': 12,
#   'Mystery': 6,
#   'Thriller': 23,
#   'Drama': 27,
#   'Comedy': 20,
#   'Action': 25,
#   'Adventure': 22,
#   'Sci-Fi': 31,
#   'Horror': 8,
#   'Fantasy': 8,
#   'Romance': 5,
#   'Children': 4,
#   'Musical': 2,
#   'War': 4,
#   'Western': 2},
#  4: {'Action': 6,
#   'Adventure': 4,
#   'Thriller': 6,
#   'Drama': 5,
#   'Mystery': 1,
#   'Comedy': 6,
#   'Romance': 2,
#   'War': 1,
#   'Western': 1,
#   'Crime': 1,
#   'Sci-Fi': 2,
#   'Children': 3,
#   'Animation': 2,
#   'Fantasy': 2,
#   'Musical': 2},
#  5: {'Comedy': 13,
#   'Drama': 13,
#   'Romance': 8,
#   'Adventure': 15,
#   'IMAX': 3,
#   'Action': 11,
#   'Sci-Fi': 7,
#   'Crime': 4,
#   'Animation': 5,
#   'Children': 7,
#   'Musical': 6,
#   'Western': 2,
#   'Thriller': 8,
#   'Fantasy': 4},
#  6: {'Adventure': 5,
#   'Animation': 1,
#   'Children': 1,
#   'Comedy': 6,
#   'Fantasy': 3,
#   'Romance': 6,
#   'Drama': 5,
#   'Action': 4,
#   'Sci-Fi': 2,
#   'Thriller': 3,
#   'Crime': 1,
#   'Mystery': 2},
#  7: {'Comedy': 45,
#   'Drama': 50,
#   'Romance': 33,
#   'Action': 30,
#   'Adventure': 30,
#   'Sci-Fi': 31,
#   'War': 9,
#   'Animation': 5,
#   'Children': 9,
#   'Musical': 4,
#   'IMAX': 1,
#   'Thriller': 18,
#   'Western': 5,
#   'Fantasy': 10,
#   'Mystery': 5,
#   'Crime': 5,
#   'Horror': 5},
#  8: {'Adventure': 12,
#   'Animation': 5,
#   'Children': 4,
#   'Comedy': 15,
#   'Fantasy': 3,
#   'Romance': 16,
#   'Action': 17,
#   'Thriller': 20,
#   'Crime': 6,
#   'Mystery': 3,
#   'Drama': 23,
#   'Musical': 3,
#   'War': 5,
#   'IMAX': 2,
#   'Horror': 3,
#   'Western': 3,
#   'Sci-Fi': 5},
#  9: {'Comedy': 3,
#   'Drama': 5,
#   'Romance': 3,
#   'War': 1,
#   'Crime': 3,
#   'Horror': 4,
#   'Mystery': 3,
#   'Thriller': 4,
#   'Action': 2},
#  10: {'Adventure': 10,
#   'Animation': 1,
#   'Children': 2,
#   'Comedy': 8,
#   'Fantasy': 3,
#   'Drama': 17,
#   'Romance': 8,
#   'Action': 12,
#   'Sci-Fi': 5,
#   'War': 8,
#   'Crime': 3,
#   'Thriller': 2,
#   'Horror': 2,
#   'Musical': 1},
#  11: {'Adventure': 119,
#   'Animation': 46,
#   'Children': 47,
#   'Comedy': 87,
#   'Fantasy': 60,
#   'Mystery': 20,
#   'Sci-Fi': 166,
#   'Thriller': 116,
#   'Romance': 45,
#   'Action': 151,
#   'Drama': 106,
#   'War': 11,
#   'IMAX': 24,
#   'Crime': 26,
#   'Horror': 50,
#   'Musical': 10,
#   'Film-Noir': 2,
#   'Western': 1,
#   'Documentary': 5},
#  12: {'Adventure': 6,
#   'Animation': 3,
#   'Children': 4,
#   'Comedy': 8,
#   'Fantasy': 4,
#   'Drama': 8,
#   'Crime': 2,
#   'Action': 7,
#   'War': 3,
#   'Sci-Fi': 3,
#   'Romance': 4,
#   'Musical': 2,
#   'IMAX': 2,
#   'Thriller': 5},
#  13: {'Adventure': 7,
#   'Animation': 1,
#   'Children': 1,
#   'Comedy': 9,
#   'Fantasy': 2,
#   'Drama': 19,
#   'Romance': 6,
#   'Mystery': 4,
#   'Sci-Fi': 6,
#   'Thriller': 15,
#   'Action': 14,
#   'War': 5,
#   'IMAX': 1,
#   'Crime': 5,
#   'Horror': 1,
#   'Western': 3},
#  14: {'Adventure': 44,
#   'Animation': 33,
#   'Children': 43,
#   'Comedy': 81,
#   'Fantasy': 20,
#   'Drama': 54,
#   'Romance': 44,
#   'IMAX': 4,
#   'Action': 15,
#   'Sci-Fi': 15,
#   'Mystery': 6,
#   'War': 4,
#   'Musical': 18,
#   'Western': 5,
#   'Thriller': 7,
#   'Crime': 6},
#  15: {'Children': 4,
#   'Drama': 9,
#   'Adventure': 2,
#   'IMAX': 2,
#   'Documentary': 1,
#   'Comedy': 3,
#   'Romance': 3,
#   'War': 2,
#   'Animation': 3,
#   'Musical': 3,
#   'Thriller': 3,
#   'Action': 1,
#   'Fantasy': 2,
#   'Crime': 1},
#  16: {'Comedy': 28,
#   'Romance': 16,
#   'Drama': 8,
#   'War': 1,
#   'Fantasy': 3,
#   'Thriller': 2,
#   'Action': 8,
#   'Adventure': 4,
#   'Musical': 1,
#   'Crime': 3,
#   'Sci-Fi': 2},
#  17: {'Action': 14,
#   'Crime': 1,
#   'Thriller': 9,
#   'Drama': 9,
#   'War': 4,
#   'Adventure': 5,
#   'Comedy': 4,
#   'Sci-Fi': 2,
#   'Romance': 2},
#  18: {'Comedy': 23,
#   'Romance': 25,
#   'Crime': 17,
#   'Drama': 57,
#   'Thriller': 9,
#   'War': 8,
#   'Adventure': 3,
#   'Animation': 1,
#   'Children': 1,
#   'Musical': 1,
#   'Action': 3,
#   'Western': 3,
#   'Sci-Fi': 2,
#   'Fantasy': 4,
#   'Film-Noir': 1,
#   'Mystery': 5},
#  19: {'Adventure': 8,
#   'Animation': 1,
#   'Children': 3,
#   'Comedy': 13,
#   'Fantasy': 4,
#   'Romance': 7,
#   'Action': 10,
#   'Crime': 5,
#   'Thriller': 12,
#   'Drama': 13,
#   'Mystery': 1,
#   'Horror': 1,
#   'Sci-Fi': 2,
#   'Musical': 1},
#  20: {'Crime': 5,
#   'Drama': 8,
#   'Thriller': 6,
#   'Comedy': 6,
#   'Action': 5,
#   'War': 1,
#   'Adventure': 6,
#   'Horror': 2,
#   'Sci-Fi': 2,
#   'Western': 1,
#   'Mystery': 1,
#   'Fantasy': 3,
#   'Animation': 1,
#   'Children': 1,
#   'Romance': 1},
#  21: {'Action': 24,
#   'Crime': 26,
#   'Thriller': 30,
#   'Drama': 57,
#   'Mystery': 10,
#   'Sci-Fi': 17,
#   'Adventure': 19,
#   'Children': 5,
#   'Comedy': 20,
#   'War': 7,
#   'Horror': 11,
#   'Romance': 8,
#   'Fantasy': 5,
#   'Western': 4,
#   'Film-Noir': 3,
#   'Animation': 2,
#   'Documentary': 2,
#   'Musical': 1},
#  22: {'Action': 45,
#   'Crime': 21,
#   'Thriller': 35,
#   'Drama': 28,
#   'Mystery': 7,
#   'Adventure': 19,
#   'War': 3,
#   'Comedy': 11,
#   'Romance': 6,
#   'Sci-Fi': 11,
#   'Horror': 2,
#   'Fantasy': 4,
#   'Animation': 1,
#   'Children': 1},
#  23: {'Adventure': 6,
#   'Animation': 4,
#   'Children': 3,
#   'Comedy': 22,
#   'Fantasy': 4,
#   'Drama': 44,
#   'Romance': 18,
#   'Mystery': 9,
#   'Sci-Fi': 8,
#   'Thriller': 30,
#   'Crime': 26,
#   'Action': 17,
#   'War': 5,
#   'Horror': 2,
#   'Documentary': 1,
#   'Film-Noir': 2,
#   'Western': 1},
#  24: {'Adventure': 43,
#   'Animation': 8,
#   'Children': 8,
#   'Comedy': 85,
#   'Fantasy': 12,
#   'Action': 69,
#   'Crime': 38,
#   'Thriller': 72,
#   'Drama': 90,
#   'Sci-Fi': 36,
#   'Romance': 41,
#   'Mystery': 18,
#   'War': 13,
#   'Horror': 19,
#   'Documentary': 2,
#   'Western': 6,
#   'Musical': 2,
#   'Film-Noir': 1},
#  25: {'Crime': 12,
#   'Drama': 29,
#   'Horror': 4,
#   'Mystery': 2,
#   'Thriller': 7,
#   'Comedy': 33,
#   'Romance': 14,
#   'War': 2,
#   'Fantasy': 9,
#   'Action': 10,
#   'Sci-Fi': 6,
#   'Adventure': 11,
#   'Western': 1,
#   'Children': 5,
#   'Musical': 1,
#   'Animation': 2},
#  26: {'Comedy': 10,
#   'Crime': 7,
#   'Thriller': 9,
#   'Romance': 7,
#   'Mystery': 2,
#   'Action': 5,
#   'Drama': 11,
#   'War': 3,
#   'Adventure': 3,
#   'IMAX': 2,
#   'Fantasy': 3,
#   'Sci-Fi': 2,
#   'Western': 1,
#   'Horror': 1,
#   'Animation': 1,
#   'Children': 1,
#   'Musical': 1},
#  27: {'Comedy': 25,
#   'Drama': 21,
#   'Romance': 14,
#   'Mystery': 2,
#   'Thriller': 10,
#   'Documentary': 3,
#   'Adventure': 13,
#   'War': 1,
#   'Western': 5,
#   'Action': 12,
#   'Sci-Fi': 6,
#   'Crime': 3,
#   'Fantasy': 1,
#   'Horror': 1,
#   'Animation': 1,
#   'Children': 1,
#   'IMAX': 2},
#  28: {'Drama': 10,
#   'Thriller': 7,
#   'War': 2,
#   'Action': 4,
#   'Crime': 4,
#   'Adventure': 3,
#   'Comedy': 8,
#   'Horror': 2,
#   'Sci-Fi': 2,
#   'Romance': 6,
#   'Children': 3,
#   'Fantasy': 2,
#   'Musical': 3,
#   'Animation': 2,
#   'IMAX': 1},
#  29: {'Action': 26,
#   'Comedy': 24,
#   'Drama': 38,
#   'Romance': 12,
#   'Adventure': 18,
#   'Crime': 17,
#   'Thriller': 22,
#   'Children': 11,
#   'Mystery': 5,
#   'Fantasy': 8,
#   'Horror': 6,
#   'War': 5,
#   'IMAX': 3,
#   'Film-Noir': 1,
#   'Sci-Fi': 7,
#   'Western': 6,
#   'Animation': 7,
#   'Musical': 6},
#  30: {'Drama': 7,
#   'Fantasy': 2,
#   'Romance': 2,
#   'Action': 5,
#   'Comedy': 4,
#   'War': 2,
#   'Animation': 2,
#   'Children': 2,
#   'Musical': 1,
#   'Thriller': 5,
#   'Sci-Fi': 5,
#   'Adventure': 1,
#   'Crime': 2,
#   'Horror': 1},
#  31: {'Action': 94,
#   'Drama': 25,
#   'War': 5,
#   'Adventure': 96,
#   'Sci-Fi': 49,
#   'Animation': 34,
#   'Children': 45,
#   'Comedy': 50,
#   'Thriller': 36,
#   'Horror': 7,
#   'Western': 6,
#   'Fantasy': 49,
#   'Romance': 10,
#   'Crime': 12,
#   'Mystery': 9,
#   'IMAX': 38,
#   'Documentary': 2},
#  32: {'Drama': 13,
#   'Romance': 8,
#   'Children': 2,
#   'Crime': 6,
#   'Mystery': 1,
#   'Thriller': 13,
#   'Comedy': 11,
#   'Adventure': 7,
#   'IMAX': 1,
#   'Action': 10,
#   'Sci-Fi': 4,
#   'Western': 1,
#   'Horror': 1,
#   'Animation': 1},
#  33: {'Drama': 9,
#   'Thriller': 4,
#   'War': 4,
#   'Action': 13,
#   'Crime': 7,
#   'Comedy': 21,
#   'Sci-Fi': 2,
#   'Adventure': 8,
#   'Fantasy': 4,
#   'Romance': 4,
#   'Horror': 2,
#   'Western': 2,
#   'Animation': 3,
#   'Children': 3,
#   'Musical': 1},
#  34: {'Adventure': 19,
#   'Animation': 7,
#   'Children': 12,
#   'Comedy': 29,
#   'Fantasy': 8,
#   'Action': 23,
#   'Thriller': 21,
#   'Drama': 17,
#   'Romance': 21,
#   'Crime': 4,
#   'Mystery': 2,
#   'Sci-Fi': 7,
#   'Musical': 6,
#   'IMAX': 3,
#   'War': 2,
#   'Western': 2},
#  35: {'Mystery': 13,
#   'Thriller': 45,
#   'Crime': 42,
#   'Action': 43,
#   'Drama': 64,
#   'War': 7,
#   'Horror': 8,
#   'Comedy': 49,
#   'Romance': 17,
#   'Adventure': 27,
#   'Animation': 11,
#   'Children': 6,
#   'Sci-Fi': 12,
#   'Fantasy': 16,
#   'Film-Noir': 2,
#   'Musical': 5,
#   'IMAX': 3,
#   'Western': 2},
#  36: {'Action': 4,
#   'Comedy': 3,
#   'Crime': 2,
#   'Drama': 5,
#   'Thriller': 5,
#   'Romance': 5,
#   'Western': 2,
#   'Horror': 1,
#   'Sci-Fi': 1,
#   'Musical': 1,
#   'War': 1,
#   'Mystery': 2,
#   'Adventure': 1},
#  37: {'Drama': 5,
#   'Romance': 1,
#   'War': 1,
#   'Comedy': 4,
#   'Horror': 1,
#   'Mystery': 3,
#   'Thriller': 4,
#   'Musical': 1,
#   'Action': 1,
#   'Crime': 2,
#   'Film-Noir': 1},
#  38: {'Comedy': 14,
#   'Romance': 14,
#   'Drama': 24,
#   'Mystery': 2,
#   'Thriller': 11,
#   'Adventure': 5,
#   'IMAX': 2,
#   'War': 4,
#   'Action': 7,
#   'Sci-Fi': 2,
#   'Crime': 1,
#   'Animation': 1,
#   'Children': 1,
#   'Musical': 1,
#   'Western': 1},
#  39: {'Adventure': 5,
#   'Animation': 1,
#   'Children': 1,
#   'Comedy': 2,
#   'Fantasy': 1,
#   'Action': 7,
#   'Crime': 3,
#   'Thriller': 7,
#   'Drama': 4,
#   'Romance': 1,
#   'Sci-Fi': 1,
#   'Mystery': 1},
#  40: {'Crime': 6,
#   'Drama': 24,
#   'Thriller': 11,
#   'Documentary': 1,
#   'Comedy': 12,
#   'Fantasy': 2,
#   'Romance': 5,
#   'Film-Noir': 2,
#   'Action': 5,
#   'Western': 1,
#   'Mystery': 4,
#   'Sci-Fi': 2,
#   'Adventure': 2,
#   'Animation': 1,
#   'Children': 1,
#   'War': 1,
#   'Horror': 2},
#  41: {'Comedy': 10,
#   'Drama': 15,
#   'Romance': 11,
#   'Fantasy': 3,
#   'Adventure': 2,
#   'War': 2,
#   'Children': 2,
#   'Sci-Fi': 1,
#   'Action': 1,
#   'Crime': 1},
#  42: {'Drama': 15,
#   'Crime': 11,
#   'Thriller': 13,
#   'Action': 13,
#   'Adventure': 8,
#   'Sci-Fi': 6,
#   'Comedy': 9,
#   'Horror': 1,
#   'Animation': 2,
#   'Children': 2,
#   'Mystery': 6,
#   'Romance': 3,
#   'Film-Noir': 1,
#   'Western': 1,
#   'War': 1,
#   'Fantasy': 3,
#   'IMAX': 1},
#  43: {'Drama': 27,
#   'Romance': 21,
#   'Comedy': 20,
#   'Crime': 5,
#   'Thriller': 9,
#   'War': 2,
#   'Children': 4,
#   'Action': 15,
#   'Adventure': 11,
#   'Fantasy': 3,
#   'Sci-Fi': 5,
#   'Animation': 3,
#   'Musical': 1,
#   'Mystery': 1,
#   'IMAX': 1},
#  44: {'Adventure': 7,
#   'Animation': 1,
#   'Comedy': 2,
#   'Crime': 1,
#   'Drama': 6,
#   'Fantasy': 4,
#   'Romance': 2,
#   'Action': 2,
#   'Western': 3},
#  45: {'Animation': 2,
#   'Children': 1,
#   'Fantasy': 3,
#   'Musical': 1,
#   'Drama': 15,
#   'Romance': 10,
#   'War': 1,
#   'Film-Noir': 3,
#   'Comedy': 8,
#   'Crime': 4,
#   'Mystery': 2,
#   'Thriller': 2,
#   'Adventure': 1},
#  46: {'Comedy': 39,
#   'Drama': 32,
#   'Romance': 14,
#   'Crime': 7,
#   'Thriller': 9,
#   'Mystery': 1,
#   'War': 3,
#   'Documentary': 3,
#   'Fantasy': 2,
#   'Action': 3,
#   'Horror': 1,
#   'Sci-Fi': 1},
#  47: {'Mystery': 2,
#   'Thriller': 8,
#   'Comedy': 13,
#   'Action': 8,
#   'Drama': 11,
#   'War': 1,
#   'Horror': 3,
#   'Sci-Fi': 4,
#   'Crime': 4,
#   'Western': 1,
#   'Adventure': 10,
#   'Children': 3,
#   'Fantasy': 8,
#   'Musical': 4,
#   'Romance': 4,
#   'Animation': 2},
#  48: {'Action': 9,
#   'Crime': 14,
#   'Thriller': 11,
#   'Drama': 49,
#   'Romance': 18,
#   'Mystery': 5,
#   'Comedy': 19,
#   'War': 11,
#   'Documentary': 1,
#   'Adventure': 9,
#   'Sci-Fi': 4,
#   'Western': 2,
#   'Horror': 1,
#   'Animation': 1,
#   'Children': 3,
#   'Fantasy': 5,
#   'Musical': 3},
#  49: {'Crime': 7,
#   'Mystery': 3,
#   'Thriller': 7,
#   'Comedy': 1,
#   'Drama': 10,
#   'Horror': 2,
#   'Action': 8,
#   'Adventure': 4,
#   'Animation': 2,
#   'Sci-Fi': 4,
#   'Fantasy': 1,
#   'War': 1,
#   'IMAX': 2},
#  50: {'Drama': 26,
#   'Romance': 13,
#   'Comedy': 14,
#   'Crime': 5,
#   'Thriller': 7,
#   'War': 3,
#   'Action': 7,
#   'Sci-Fi': 4,
#   'Adventure': 8,
#   'Fantasy': 6,
#   'Animation': 3,
#   'Children': 2,
#   'Musical': 1},
#  51: {'Mystery': 9,
#   'Thriller': 14,
#   'Crime': 19,
#   'Adventure': 9,
#   'Comedy': 36,
#   'Drama': 15,
#   'Action': 19,
#   'Fantasy': 4,
#   'Horror': 5,
#   'Film-Noir': 1,
#   'Sci-Fi': 6,
#   'Romance': 6,
#   'Musical': 1,
#   'Western': 2,
#   'War': 2},
#  52: {'Children': 2,
#   'Drama': 4,
#   'Action': 3,
#   'War': 2,
#   'Romance': 2,
#   'Western': 1,
#   'Adventure': 2,
#   'Comedy': 2,
#   'Thriller': 4,
#   'Fantasy': 1,
#   'Sci-Fi': 1},
#  53: {'Comedy': 32,
#   'Crime': 12,
#   'Thriller': 10,
#   'Adventure': 3,
#   'Drama': 69,
#   'Fantasy': 3,
#   'Mystery': 9,
#   'Sci-Fi': 4,
#   'Romance': 18,
#   'Documentary': 5,
#   'Musical': 1,
#   'Animation': 1,
#   'Western': 1,
#   'Film-Noir': 2,
#   'War': 5,
#   'Children': 1,
#   'Action': 4,
#   'Horror': 2},
#  54: {'Adventure': 91,
#   'Animation': 7,
#   'Children': 16,
#   'Comedy': 122,
#   'Fantasy': 34,
#   'Action': 122,
#   'Thriller': 119,
#   'Drama': 130,
#   'Romance': 48,
#   'Mystery': 22,
#   'Sci-Fi': 70,
#   'Crime': 54,
#   'Horror': 34,
#   'War': 18,
#   'Western': 13,
#   'Documentary': 3,
#   'Film-Noir': 2,
#   'Musical': 5},
#  55: {'Action': 7,
#   'Adventure': 5,
#   'Sci-Fi': 2,
#   'Crime': 2,
#   'Drama': 6,
#   'Horror': 1,
#   'Romance': 1,
#   'War': 1,
#   'Thriller': 1},
#  56: {'Drama': 56,
#   'Romance': 20,
#   'Mystery': 12,
#   'Thriller': 28,
#   'Crime': 23,
#   'Comedy': 18,
#   'Action': 11,
#   'War': 12,
#   'Documentary': 1,
#   'Western': 3,
#   'Horror': 9,
#   'Adventure': 6,
#   'Fantasy': 4,
#   'Film-Noir': 3,
#   'Sci-Fi': 5,
#   'Musical': 2,
#   'Animation': 1},
#  57: {'Action': 4,
#   'Adventure': 6,
#   'Sci-Fi': 1,
#   'Thriller': 1,
#   'Drama': 4,
#   'Western': 3,
#   'Children': 3,
#   'Fantasy': 3,
#   'Musical': 1,
#   'Romance': 2,
#   'War': 2,
#   'Comedy': 3,
#   'Crime': 2,
#   'Animation': 1},
#  58: {'Adventure': 39,
#   'Animation': 9,
#   'Children': 13,
#   'Comedy': 83,
#   'Fantasy': 23,
#   'Action': 62,
#   'Crime': 66,
#   'Thriller': 105,
#   'Drama': 165,
#   'Romance': 56,
#   'Mystery': 44,
#   'Sci-Fi': 38,
#   'War': 25,
#   'Documentary': 4,
#   'Horror': 38,
#   'Musical': 3,
#   'Western': 8,
#   'Film-Noir': 13,
#   'IMAX': 3},
#  59: {'Adventure': 1,
#   'Animation': 1,
#   'Children': 2,
#   'Comedy': 10,
#   'Fantasy': 5,
#   'Crime': 3,
#   'Mystery': 1,
#   'Thriller': 1,
#   'Drama': 6,
#   'Romance': 4,
#   'War': 2,
#   'Sci-Fi': 1},
#  60: {'Comedy': 11,
#   'War': 3,
#   'Crime': 3,
#   'Drama': 20,
#   'Adventure': 21,
#   'Animation': 1,
#   'Children': 4,
#   'Musical': 3,
#   'IMAX': 7,
#   'Fantasy': 15,
#   'Action': 8,
#   'Romance': 6,
#   'Mystery': 3,
#   'Sci-Fi': 2,
#   'Thriller': 5,
#   'Documentary': 1},
#  61: {'Drama': 65,
#   'Comedy': 58,
#   'Romance': 31,
#   'Mystery': 8,
#   'Thriller': 32,
#   'Crime': 22,
#   'Adventure': 24,
#   'Animation': 4,
#   'Children': 3,
#   'Musical': 2,
#   'IMAX': 3,
#   'Horror': 9,
#   'Action': 22,
#   'Sci-Fi': 14,
#   'Fantasy': 16,
#   'Western': 1,
#   'Documentary': 4},
#  62: {'Action': 2,
#   'Adventure': 4,
#   'Crime': 3,
#   'Thriller': 2,
#   'Comedy': 10,
#   'Drama': 7,
#   'Fantasy': 2,
#   'Sci-Fi': 3,
#   'Romance': 2,
#   'Animation': 1,
#   'Musical': 1},
#  63: {'Drama': 15,
#   'War': 13,
#   'Comedy': 4,
#   'Romance': 6,
#   'Adventure': 4,
#   'Documentary': 2,
#   'Action': 7,
#   'Sci-Fi': 2,
#   'Crime': 1,
#   'Western': 1,
#   'Musical': 1,
#   'Mystery': 1},
#  64: {'Mystery': 1,
#   'Thriller': 8,
#   'Action': 8,
#   'Drama': 11,
#   'War': 2,
#   'Adventure': 7,
#   'IMAX': 3,
#   'Comedy': 1,
#   'Crime': 5,
#   'Horror': 1,
#   'Sci-Fi': 3,
#   'Animation': 2,
#   'Children': 2,
#   'Musical': 2,
#   'Western': 1,
#   'Fantasy': 1,
#   'Romance': 2},
#  65: {'Drama': 34,
#   'Sci-Fi': 10,
#   'Crime': 6,
#   'Comedy': 12,
#   'Romance': 14,
#   'War': 4,
#   'Adventure': 9,
#   'Animation': 5,
#   'Children': 6,
#   'Musical': 4,
#   'IMAX': 3,
#   'Documentary': 2,
#   'Action': 7,
#   'Thriller': 12,
#   'Fantasy': 7,
#   'Horror': 3,
#   'Mystery': 5},
#  66: {'Adventure': 8,
#   'Animation': 5,
#   'Children': 5,
#   'Comedy': 25,
#   'Fantasy': 1,
#   'Crime': 6,
#   'Thriller': 5,
#   'Drama': 15,
#   'Action': 12,
#   'War': 5,
#   'Romance': 10,
#   'Sci-Fi': 5,
#   'Western': 1,
#   'Musical': 1},
#  67: {'Drama': 10,
#   'Romance': 5,
#   'Action': 10,
#   'War': 3,
#   'Adventure': 11,
#   'Sci-Fi': 6,
#   'Western': 2,
#   'Thriller': 3,
#   'Comedy': 8,
#   'Fantasy': 5,
#   'Crime': 1,
#   'Horror': 1},
#  68: {'Action': 2,
#   'Adventure': 3,
#   'Thriller': 2,
#   'Children': 1,
#   'Drama': 7,
#   'Comedy': 6,
#   'Romance': 2,
#   'Sci-Fi': 2,
#   'Crime': 1,
#   'Western': 1},
#  69: {'Adventure': 24,
#   'Animation': 8,
#   'Children': 9,
#   'Comedy': 30,
#   'Fantasy': 14,
#   'Action': 35,
#   'Crime': 17,
#   'Thriller': 32,
#   'Mystery': 6,
#   'Sci-Fi': 15,
#   'Horror': 9,
#   'Drama': 22,
#   'Romance': 6,
#   'Western': 4,
#   'War': 7,
#   'Musical': 7,
#   'IMAX': 1},
#  70: {'Action': 25,
#   'Crime': 28,
#   'Thriller': 27,
#   'Drama': 39,
#   'Comedy': 19,
#   'Horror': 2,
#   'War': 5,
#   'Fantasy': 1,
#   'Adventure': 3,
#   'Sci-Fi': 4,
#   'Romance': 3,
#   'Mystery': 4,
#   'Documentary': 3},
#  71: {'Crime': 6,
#   'Drama': 22,
#   'Comedy': 5,
#   'Romance': 8,
#   'War': 3,
#   'Action': 7,
#   'Adventure': 2,
#   'Thriller': 4,
#   'IMAX': 4,
#   'Mystery': 1,
#   'Sci-Fi': 4},
#  72: {'Mystery': 2,
#   'Sci-Fi': 10,
#   'Thriller': 16,
#   'Children': 2,
#   'Drama': 34,
#   'Comedy': 28,
#   'Romance': 17,
#   'Action': 14,
#   'War': 4,
#   'Adventure': 9,
#   'IMAX': 1,
#   'Crime': 10,
#   'Western': 2,
#   'Horror': 2,
#   'Fantasy': 8,
#   'Musical': 3},
#  73: {'Children': 8,
#   'Drama': 79,
#   'Crime': 17,
#   'Mystery': 6,
#   'Thriller': 11,
#   'Action': 6,
#   'War': 7,
#   'Adventure': 8,
#   'IMAX': 2,
#   'Documentary': 1,
#   'Comedy': 29,
#   'Western': 3,
#   'Animation': 3,
#   'Fantasy': 6,
#   'Musical': 3,
#   'Romance': 16,
#   'Sci-Fi': 3,
#   'Horror': 3,
#   'Film-Noir': 1},
#  74: {'Drama': 21,
#   'Romance': 10,
#   'Comedy': 14,
#   'Crime': 5,
#   'Thriller': 4,
#   'Mystery': 4,
#   'Film-Noir': 2,
#   'Horror': 2,
#   'Adventure': 2,
#   'Fantasy': 2,
#   'Sci-Fi': 1},
#  75: {'Action': 17,
#   'Adventure': 12,
#   'Thriller': 19,
#   'Comedy': 8,
#   'Crime': 6,
#   'Romance': 5,
#   'Drama': 14,
#   'IMAX': 1,
#   'War': 2,
#   'Sci-Fi': 6,
#   'Western': 2,
#   'Children': 1,
#   'Horror': 1,
#   'Mystery': 1,
#   'Fantasy': 2},
#  76: {'Mystery': 1,
#   'Thriller': 6,
#   'Action': 14,
#   'Drama': 19,
#   'War': 6,
#   'Adventure': 9,
#   'Sci-Fi': 7,
#   'Comedy': 7,
#   'Crime': 3,
#   'Children': 3,
#   'Fantasy': 2,
#   'Romance': 4,
#   'Horror': 1,
#   'Animation': 1},
#  77: {'Action': 21,
#   'Adventure': 17,
#   'Sci-Fi': 19,
#   'Thriller': 10,
#   'Animation': 5,
#   'Children': 2,
#   'Fantasy': 8,
#   'Musical': 1,
#   'Comedy': 11,
#   'War': 6,
#   'Drama': 23,
#   'Romance': 1,
#   'Horror': 8,
#   'Crime': 7,
#   'Mystery': 4,
#   'Western': 1},
#  78: {'Adventure': 18,
#   'Drama': 8,
#   'Fantasy': 7,
#   'Mystery': 2,
#   'Sci-Fi': 19,
#   'Action': 20,
#   'Crime': 3,
#   'Thriller': 8,
#   'Children': 3,
#   'Comedy': 4,
#   'Musical': 2,
#   'War': 1,
#   'Animation': 1,
#   'Romance': 2},
#  79: {'Action': 2,
#   'Drama': 10,
#   'War': 1,
#   'Comedy': 6,
#   'Romance': 7,
#   'Crime': 2,
#   'Horror': 1,
#   'Thriller': 1,
#   'Adventure': 1,
#   'Fantasy': 1},
#  80: {'Crime': 3,
#   'Drama': 7,
#   'Romance': 4,
#   'Comedy': 4,
#   'Action': 3,
#   'Adventure': 2,
#   'Sci-Fi': 2,
#   'Thriller': 3,
#   'Children': 1,
#   'Fantasy': 1,
#   'Musical': 1},
#  81: {'Comedy': 2,
#   'Drama': 12,
#   'Romance': 3,
#   'War': 11,
#   'Crime': 2,
#   'Horror': 1,
#   'Thriller': 4,
#   'Action': 10,
#   'Adventure': 4,
#   'Sci-Fi': 2},
#  82: {'Adventure': 25,
#   'Animation': 13,
#   'Children': 14,
#   'Comedy': 39,
#   'Fantasy': 16,
#   'Crime': 52,
#   'Drama': 122,
#   'Mystery': 21,
#   'Thriller': 51,
#   'Action': 48,
#   'War': 17,
#   'Romance': 23,
#   'Sci-Fi': 13,
#   'Film-Noir': 3,
#   'Horror': 4,
#   'Documentary': 12,
#   'Musical': 2,
#   'IMAX': 6,
#   'Western': 1},
#  83: {'Crime': 5,
#   'Mystery': 3,
#   'Thriller': 7,
#   'Action': 3,
#   'Drama': 7,
#   'Comedy': 8,
#   'Horror': 4,
#   'Adventure': 4,
#   'Fantasy': 4,
#   'Romance': 3,
#   'Musical': 1},
#  84: {'Adventure': 5,
#   'Animation': 2,
#   'Children': 3,
#   'Comedy': 4,
#   'Fantasy': 3,
#   'Drama': 3,
#   'IMAX': 1,
#   'Action': 4,
#   'Crime': 3,
#   'Thriller': 4,
#   'Horror': 2,
#   'Sci-Fi': 1,
#   'Musical': 1,
#   'Western': 1,
#   'Romance': 1},
#  85: {'Drama': 19,
#   'Romance': 10,
#   'Children': 9,
#   'Comedy': 16,
#   'Musical': 7,
#   'Crime': 6,
#   'Mystery': 5,
#   'Thriller': 4,
#   'Animation': 8,
#   'Fantasy': 4,
#   'Action': 3,
#   'Adventure': 6,
#   'War': 2,
#   'Western': 1,
#   'Sci-Fi': 1,
#   'IMAX': 2},
#  86: {'Action': 11,
#   'Adventure': 10,
#   'Sci-Fi': 7,
#   'Crime': 11,
#   'Drama': 11,
#   'Comedy': 4,
#   'Mystery': 1,
#   'Thriller': 6,
#   'Western': 1,
#   'War': 1,
#   'IMAX': 2,
#   'Animation': 1,
#   'Children': 1,
#   'Romance': 1},
#  87: {'Comedy': 7,
#   'Drama': 13,
#   'Romance': 5,
#   'Crime': 9,
#   'Thriller': 13,
#   'Mystery': 1,
#   'Adventure': 5,
#   'IMAX': 1,
#   'Action': 8,
#   'War': 1,
#   'Fantasy': 1,
#   'Sci-Fi': 2,
#   'Western': 1,
#   'Horror': 1},
#  88: {'Crime': 10,
#   'Drama': 37,
#   'Romance': 12,
#   'Comedy': 30,
#   'Thriller': 18,
#   'Mystery': 6,
#   'Sci-Fi': 13,
#   'Action': 21,
#   'War': 9,
#   'Adventure': 16,
#   'Animation': 3,
#   'Children': 5,
#   'Musical': 2,
#   'Fantasy': 7,
#   'Western': 4,
#   'Horror': 5},
#  89: {'Crime': 12,
#   'Drama': 33,
#   'Thriller': 26,
#   'War': 5,
#   'Romance': 6,
#   'Action': 10,
#   'Adventure': 7,
#   'Sci-Fi': 2,
#   'Mystery': 8,
#   'Comedy': 7,
#   'Horror': 6,
#   'Fantasy': 4,
#   'Animation': 1,
#   'Children': 1},
#  90: {'Adventure': 39,
#   'Animation': 10,
#   'Children': 13,
#   'Comedy': 34,
#   'Fantasy': 14,
#   'Action': 31,
#   'Thriller': 23,
#   'Drama': 26,
#   'Mystery': 4,
#   'IMAX': 8,
#   'Horror': 6,
#   'Sci-Fi': 20,
#   'Crime': 12,
#   'Romance': 10,
#   'War': 2,
#   'Musical': 5,
#   'Western': 2},
#  91: {'Adventure': 107,
#   'Animation': 39,
#   'Children': 49,
#   'Comedy': 165,
#   'Fantasy': 57,
#   'Action': 92,
#   'Thriller': 72,
#   'Drama': 181,
#   'Romance': 64,
#   'Crime': 57,
#   'Horror': 20,
#   'Mystery': 34,
#   'Sci-Fi': 54,
#   'War': 53,
#   'Musical': 35,
#   'IMAX': 5,
#   'Western': 18,
#   'Documentary': 6,
#   'Film-Noir': 2},
#  92: {'Documentary': 1,
#   'Drama': 10,
#   'Romance': 2,
#   'Crime': 4,
#   'Mystery': 4,
#   'Thriller': 5,
#   'Comedy': 3,
#   'Fantasy': 3,
#   'Adventure': 3,
#   'Animation': 1,
#   'Children': 1,
#   'Action': 1,
#   'Horror': 2},
#  93: {'Adventure': 10,
#   'Animation': 3,
#   'Children': 6,
#   'Comedy': 21,
#   'Fantasy': 7,
#   'Crime': 2,
#   'Drama': 13,
#   'Horror': 1,
#   'Mystery': 1,
#   'Thriller': 3,
#   'War': 2,
#   'Musical': 3,
#   'IMAX': 2,
#   'Action': 7,
#   'Sci-Fi': 4,
#   'Romance': 3},
#  94: {'Adventure': 6,
#   'Drama': 9,
#   'IMAX': 1,
#   'Romance': 4,
#   'War': 2,
#   'Western': 1,
#   'Mystery': 2,
#   'Thriller': 6,
#   'Action': 6,
#   'Comedy': 4,
#   'Crime': 1,
#   'Animation': 2,
#   'Children': 2,
#   'Fantasy': 1,
#   'Sci-Fi': 1,
#   'Horror': 1},
#  95: {'Mystery': 1,
#   'Sci-Fi': 1,
#   'Thriller': 1,
#   'Drama': 7,
#   'Romance': 4,
#   'War': 1,
#   'Comedy': 3},
#  96: {'Adventure': 88,
#   'Animation': 35,
#   'Children': 35,
#   'Comedy': 95,
#   'Fantasy': 40,
#   'Romance': 36,
#   'Drama': 129,
#   'Mystery': 34,
#   'Sci-Fi': 60,
#   'Thriller': 79,
#   'Action': 103,
#   'Crime': 72,
#   'War': 12,
#   'Musical': 10,
#   'Western': 10,
#   'Horror': 8,
#   'Film-Noir': 4,
#   'IMAX': 32,
#   'Documentary': 1},
#  97: {'Adventure': 3,
#   'Animation': 2,
#   'Children': 2,
#   'Comedy': 18,
#   'Fantasy': 7,
#   'Drama': 11,
#   'Romance': 8,
#   'War': 1},
#  98: {'Mystery': 4,
#   'Thriller': 9,
#   'Comedy': 7,
#   'Crime': 7,
#   'Drama': 16,
#   'Romance': 7,
#   'War': 1,
#   'Animation': 4,
#   'Sci-Fi': 8,
#   'Action': 11,
#   'Adventure': 15,
#   'Film-Noir': 1,
#   'Children': 3,
#   'Fantasy': 12,
#   'IMAX': 12,
#   'Musical': 1,
#   'Western': 1},
#  99: {'Mystery': 7,
#   'Thriller': 10,
#   'Comedy': 15,
#   'Crime': 13,
#   'Drama': 7,
#   'Horror': 2,
#   'Adventure': 2,
#   'Fantasy': 1,
#   'Action': 5,
#   'Western': 1,
#   'Romance': 3,
#   'Sci-Fi': 4,
#   'Film-Noir': 1,
#   'Animation': 1,
#   'Children': 1},
#  100: {'Drama': 14,
#   'Romance': 5,
#   'Crime': 7,
#   'Mystery': 2,
#   'Thriller': 7,
#   'Documentary': 1,
#   'Comedy': 14,
#   'Action': 7,
#   'Adventure': 5,
#   'Sci-Fi': 6,
#   'Fantasy': 2,
#   'War': 2,
#   'Horror': 2,
#   'Animation': 2,
#   'Children': 1},
#  101: {'Action': 17,
#   'Crime': 13,
#   'Thriller': 27,
#   'Adventure': 8,
#   'Comedy': 24,
#   'Drama': 28,
#   'Romance': 16,
#   'Mystery': 2,
#   'Animation': 4,
#   'Children': 3,
#   'Musical': 3,
#   'War': 3,
#   'Western': 1,
#   'Documentary': 1,
#   'Sci-Fi': 4,
#   'IMAX': 1,
#   'Fantasy': 1,
#   'Horror': 2},
#  102: {'Mystery': 6,
#   'Sci-Fi': 13,
#   'Thriller': 11,
#   'Action': 12,
#   'Adventure': 8,
#   'Crime': 9,
#   'Drama': 19,
#   'Comedy': 14,
#   'War': 2,
#   'Musical': 3,
#   'Romance': 8,
#   'Fantasy': 4,
#   'Children': 2,
#   'Western': 4,
#   'Horror': 2,
#   'IMAX': 2,
#   'Animation': 1},
#  103: {'Comedy': 66,
#   'Romance': 49,
#   'Drama': 35,
#   'Musical': 2,
#   'Horror': 3,
#   'Crime': 7,
#   'Action': 9,
#   'Adventure': 11,
#   'Sci-Fi': 4,
#   'Thriller': 5,
#   'Fantasy': 5,
#   'Animation': 6,
#   'Children': 11,
#   'Western': 1,
#   'War': 2,
#   'Mystery': 2,
#   'IMAX': 1},
#  104: {'Drama': 438,
#   'Romance': 144,
#   'Comedy': 225,
#   'Crime': 85,
#   'Thriller': 99,
#   'Adventure': 70,
#   'Fantasy': 42,
#   'Mystery': 57,
#   'Sci-Fi': 35,
#   'Children': 38,
#   'War': 58,
#   'Action': 60,
#   'Documentary': 17,
#   'Film-Noir': 21,
#   'Musical': 47,
#   'Horror': 29,
#   'Animation': 25,
#   'Western': 18,
#   'IMAX': 1},
#  105: {'Adventure': 6,
#   'Animation': 1,
#   'Children': 2,
#   'Comedy': 8,
#   'Fantasy': 3,
#   'Mystery': 1,
#   'Sci-Fi': 6,
#   'Thriller': 6,
#   'Action': 5,
#   'Romance': 4,
#   'Crime': 1,
#   'Drama': 2,
#   'War': 1},
#  106: {'Crime': 15,
#   'Drama': 18,
#   'Thriller': 7,
#   'Comedy': 4,
#   'Mystery': 1,
#   'Film-Noir': 1,
#   'Action': 3,
#   'Romance': 1},
#  107: {'Adventure': 17,
#   'Animation': 9,
#   'Children': 9,
#   'Comedy': 18,
#   'Fantasy': 6,
#   'Drama': 5,
#   'Romance': 3,
#   'War': 1,
#   'Musical': 4,
#   'Action': 14,
#   'Sci-Fi': 16,
#   'Thriller': 3,
#   'Western': 1,
#   'Crime': 2,
#   'IMAX': 2,
#   'Mystery': 1},
#  108: {'Drama': 13,
#   'Mystery': 3,
#   'Sci-Fi': 1,
#   'Thriller': 7,
#   'Comedy': 12,
#   'Romance': 5,
#   'Crime': 4,
#   'War': 1,
#   'Action': 3,
#   'Western': 1,
#   'Adventure': 4,
#   'Documentary': 1,
#   'Animation': 3,
#   'Children': 3,
#   'Musical': 3,
#   'IMAX': 1,
#   'Horror': 1,
#   'Fantasy': 1},
#  109: {'Mystery': 6,
#   'Sci-Fi': 6,
#   'Thriller': 12,
#   'Drama': 41,
#   'Fantasy': 14,
#   'Romance': 11,
#   'Crime': 15,
#   'Comedy': 26,
#   'War': 4,
#   'Animation': 6,
#   'Children': 6,
#   'Musical': 6,
#   'Action': 12,
#   'Adventure': 14,
#   'Horror': 2,
#   'Film-Noir': 1,
#   'Western': 1,
#   'IMAX': 1},
#  110: {'Children': 3,
#   'Drama': 28,
#   'Adventure': 13,
#   'IMAX': 1,
#   'Crime': 5,
#   'Comedy': 16,
#   'Romance': 9,
#   'War': 5,
#   'Action': 11,
#   'Thriller': 7,
#   'Sci-Fi': 4,
#   'Western': 2,
#   'Fantasy': 5,
#   'Horror': 1,
#   'Mystery': 2,
#   'Musical': 1},
#  111: {'Crime': 1,
#   'Drama': 7,
#   'War': 1,
#   'Children': 1,
#   'Comedy': 8,
#   'Fantasy': 2,
#   'Horror': 1,
#   'Romance': 6,
#   'Action': 1},
#  112: {'Crime': 10,
#   'Drama': 36,
#   'Comedy': 23,
#   'Thriller': 9,
#   'Romance': 14,
#   'War': 4,
#   'Mystery': 7,
#   'Adventure': 5,
#   'Fantasy': 4,
#   'Action': 7,
#   'Horror': 3,
#   'Sci-Fi': 4,
#   'Documentary': 3,
#   'Musical': 1,
#   'Children': 1,
#   'IMAX': 1},
#  113: {'Comedy': 8,
#   'Romance': 9,
#   'Drama': 14,
#   'Crime': 3,
#   'Horror': 1,
#   'Thriller': 4,
#   'Action': 3,
#   'War': 2,
#   'Adventure': 2,
#   'Animation': 2,
#   'Children': 2,
#   'Fantasy': 1,
#   'Sci-Fi': 1,
#   'Musical': 1},
#  114: {'Comedy': 11,
#   'Romance': 12,
#   'Drama': 24,
#   'Action': 5,
#   'Sci-Fi': 2,
#   'Thriller': 10,
#   'Crime': 4,
#   'Documentary': 2,
#   'Adventure': 4,
#   'Horror': 2,
#   'Children': 2,
#   'Fantasy': 1,
#   'Musical': 1,
#   'War': 1},
#  115: {'Mystery': 8,
#   'Thriller': 18,
#   'Comedy': 11,
#   'Crime': 17,
#   'Drama': 25,
#   'Romance': 6,
#   'Action': 10,
#   'Adventure': 5,
#   'Sci-Fi': 4,
#   'Horror': 1,
#   'Animation': 2,
#   'Fantasy': 2,
#   'Children': 1,
#   'War': 2,
#   'IMAX': 3},
#  116: {'Adventure': 118,
#   'Animation': 35,
#   'Children': 40,
#   'Comedy': 205,
#   'Fantasy': 40,
#   'Crime': 91,
#   'Drama': 176,
#   'Thriller': 159,
#   'Mystery': 27,
#   'Sci-Fi': 83,
#   'Action': 203,
#   'Horror': 40,
#   'Musical': 20,
#   'War': 34,
#   'IMAX': 7,
#   'Romance': 39,
#   'Western': 10,
#   'Film-Noir': 2,
#   'Documentary': 3},
#  117: {'Comedy': 9,
#   'Romance': 10,
#   'Action': 12,
#   'Drama': 15,
#   'Thriller': 12,
#   'Adventure': 6,
#   'Western': 1,
#   'Crime': 6,
#   'War': 3,
#   'Musical': 1},
#  118: {'Crime': 4,
#   'Mystery': 2,
#   'Thriller': 5,
#   'Comedy': 7,
#   'Drama': 12,
#   'Adventure': 1,
#   'Children': 1,
#   'Fantasy': 2,
#   'Musical': 1,
#   'Romance': 3,
#   'Action': 1,
#   'War': 1,
#   'Film-Noir': 1,
#   'Documentary': 1},
#  119: {'Adventure': 7,
#   'Children': 11,
#   'Fantasy': 8,
#   'Drama': 10,
#   'Animation': 8,
#   'Musical': 7,
#   'Romance': 5,
#   'IMAX': 3,
#   'Horror': 1,
#   'Sci-Fi': 1,
#   'Action': 2,
#   'Crime': 2,
#   'Thriller': 2,
#   'Comedy': 4,
#   'War': 1,
#   'Western': 1},
#  120: {'Comedy': 7,
#   'Crime': 4,
#   'Thriller': 7,
#   'Drama': 14,
#   'Mystery': 2,
#   'Adventure': 5,
#   'IMAX': 2,
#   'War': 3,
#   'Romance': 6,
#   'Animation': 1,
#   'Children': 3,
#   'Musical': 1,
#   'Action': 3,
#   'Sci-Fi': 2,
#   'Fantasy': 1,
#   'Western': 1},
#  121: {'Comedy': 32,
#   'Action': 21,
#   'Adventure': 14,
#   'Sci-Fi': 8,
#   'Crime': 16,
#   'Drama': 23,
#   'Thriller': 11,
#   'Mystery': 1,
#   'War': 3,
#   'Children': 3,
#   'Romance': 5,
#   'IMAX': 2,
#   'Fantasy': 3},
#  122: {'Drama': 32,
#   'Romance': 14,
#   'Comedy': 9,
#   'Fantasy': 2,
#   'War': 4,
#   'Mystery': 2,
#   'Crime': 2,
#   'Sci-Fi': 1,
#   'Thriller': 2,
#   'Action': 1,
#   'Adventure': 1,
#   'Film-Noir': 1},
#  123: {'Action': 2,
#   'Adventure': 2,
#   'Thriller': 4,
#   'Comedy': 8,
#   'Crime': 4,
#   'Drama': 6,
#   'Children': 2},
#  124: {'Adventure': 34,
#   'Animation': 8,
#   'Children': 9,
#   'Comedy': 65,
#   'Fantasy': 15,
#   'Action': 62,
#   'Crime': 45,
#   'Thriller': 68,
#   'Drama': 62,
#   'Horror': 5,
#   'Mystery': 20,
#   'Sci-Fi': 29,
#   'IMAX': 3,
#   'Romance': 41,
#   'Western': 3,
#   'War': 2,
#   'Musical': 4,
#   'Film-Noir': 2},
#  125: {'Drama': 21,
#   'Musical': 1,
#   'Crime': 10,
#   'Mystery': 25,
#   'Thriller': 20,
#   'Adventure': 1,
#   'Comedy': 2,
#   'Fantasy': 3,
#   'Romance': 3,
#   'Horror': 5,
#   'Film-Noir': 1,
#   'Sci-Fi': 7,
#   'Animation': 1},
#  126: {'Adventure': 3,
#   'Animation': 1,
#   'Children': 2,
#   'Comedy': 6,
#   'Fantasy': 2,
#   'Romance': 1,
#   'Drama': 6,
#   'Action': 3,
#   'Sci-Fi': 1,
#   'Crime': 2,
#   'Thriller': 5,
#   'Mystery': 1,
#   'Musical': 1},
#  127: {'Comedy': 8,
#   'Action': 16,
#   'Crime': 3,
#   'Drama': 15,
#   'Horror': 1,
#   'Mystery': 3,
#   'Thriller': 17,
#   'Adventure': 10,
#   'War': 2,
#   'Romance': 7,
#   'IMAX': 3,
#   'Sci-Fi': 4,
#   'Fantasy': 3,
#   'Animation': 4,
#   'Children': 4,
#   'Musical': 4},
#  128: {'Action': 19,
#   'Drama': 11,
#   'War': 2,
#   'Adventure': 11,
#   'IMAX': 1,
#   'Crime': 5,
#   'Thriller': 11,
#   'Comedy': 17,
#   'Western': 1,
#   'Romance': 6,
#   'Sci-Fi': 7,
#   'Musical': 1,
#   'Horror': 1},
#  129: {'Adventure': 38,
#   'Animation': 18,
#   'Children': 25,
#   'Comedy': 81,
#   'Fantasy': 27,
#   'Crime': 14,
#   'Romance': 33,
#   'Drama': 62,
#   'War': 4,
#   'Musical': 9,
#   'IMAX': 8,
#   'Mystery': 12,
#   'Thriller': 29,
#   'Sci-Fi': 13,
#   'Action': 15,
#   'Horror': 20,
#   'Documentary': 6},
#  130: {'Action': 27,
#   'Crime': 20,
#   'Thriller': 39,
#   'Drama': 72,
#   'Comedy': 27,
#   'Horror': 3,
#   'Mystery': 8,
#   'Romance': 21,
#   'Sci-Fi': 12,
#   'War': 16,
#   'Adventure': 17,
#   'Western': 5,
#   'Musical': 1,
#   'Fantasy': 4,
#   'Children': 1},
#  131: {'Drama': 103,
#   'Romance': 56,
#   'Comedy': 112,
#   'Mystery': 11,
#   'Sci-Fi': 20,
#   'Thriller': 45,
#   'Children': 25,
#   'Action': 61,
#   'War': 9,
#   'Crime': 27,
#   'Adventure': 51,
#   'IMAX': 5,
#   'Horror': 7,
#   'Animation': 13,
#   'Musical': 11,
#   'Fantasy': 18,
#   'Western': 3,
#   'Documentary': 1},
#  132: {'Drama': 100,
#   'Romance': 27,
#   'Adventure': 24,
#   'Fantasy': 21,
#   'Mystery': 16,
#   'Sci-Fi': 18,
#   'Thriller': 40,
#   'Children': 14,
#   'Comedy': 78,
#   'Crime': 41,
#   'Action': 14,
#   'Animation': 7,
#   'Musical': 10,
#   'Horror': 16,
#   'Film-Noir': 3,
#   'War': 3,
#   'Documentary': 1},
#  133: {'Adventure': 28,
#   'Animation': 22,
#   'Children': 23,
#   'Comedy': 69,
#   'Fantasy': 28,
#   'Action': 43,
#   'Crime': 66,
#   'Thriller': 63,
#   'Drama': 154,
#   'Mystery': 35,
#   'Sci-Fi': 23,
#   'Romance': 56,
#   'War': 15,
#   'Musical': 10,
#   'Horror': 5,
#   'IMAX': 14,
#   'Film-Noir': 8,
#   'Documentary': 12,
#   'Western': 1},
#  134: {'Adventure': 13,
#   'Animation': 2,
#   'Children': 6,
#   'Comedy': 53,
#   'Fantasy': 10,
#   'Crime': 29,
#   'Drama': 87,
#   'Romance': 15,
#   'Thriller': 38,
#   'Mystery': 10,
#   'Action': 23,
#   'War': 7,
#   'Documentary': 6,
#   'Sci-Fi': 18,
#   'Western': 2,
#   'Horror': 24,
#   'Musical': 3,
#   'Film-Noir': 3},
#  135: {'Adventure': 34,
#   'Animation': 16,
#   'Children': 29,
#   'Comedy': 35,
#   'Fantasy': 20,
#   'Drama': 45,
#   'Romance': 30,
#   'War': 9,
#   'Action': 22,
#   'IMAX': 4,
#   'Crime': 7,
#   'Thriller': 8,
#   'Musical': 12,
#   'Sci-Fi': 9,
#   'Mystery': 3,
#   'Horror': 1,
#   'Western': 2,
#   'Documentary': 1},
#  136: {'Adventure': 32,
#   'Animation': 11,
#   'Children': 12,
#   'Comedy': 16,
#   'Fantasy': 13,
#   'Drama': 19,
#   'IMAX': 19,
#   'Romance': 5,
#   'War': 3,
#   'Musical': 4,
#   'Sci-Fi': 20,
#   'Action': 27,
#   'Crime': 9,
#   'Thriller': 12,
#   'Mystery': 5,
#   'Horror': 1,
#   'Film-Noir': 1,
#   'Western': 1},
#  137: {'Adventure': 63,
#   'Animation': 22,
#   'Children': 28,
#   'Comedy': 80,
#   'Fantasy': 35,
#   'Action': 73,
#   'Crime': 36,
#   'Thriller': 60,
#   'Romance': 40,
#   'Horror': 24,
#   'Drama': 103,
#   'War': 15,
#   'Sci-Fi': 39,
#   'Musical': 23,
#   'IMAX': 1,
#   'Mystery': 18,
#   'Film-Noir': 2,
#   'Western': 1},
#  138: {'Action': 10,
#   'Drama': 25,
#   'War': 5,
#   'Comedy': 12,
#   'Crime': 12,
#   'Thriller': 14,
#   'Romance': 15,
#   'Horror': 2,
#   'Adventure': 7,
#   'Film-Noir': 1,
#   'Mystery': 6,
#   'Sci-Fi': 1,
#   'Fantasy': 2,
#   'Children': 2,
#   'Animation': 1},
#  139: {'Adventure': 1,
#   'Comedy': 6,
#   'Crime': 3,
#   'Thriller': 4,
#   'Drama': 2,
#   'Romance': 3,
#   'Horror': 1,
#   'Action': 2,
#   'Mystery': 1},
#  140: {'Adventure': 42,
#   'Animation': 5,
#   'Children': 5,
#   'Comedy': 89,
#   'Fantasy': 16,
#   'Action': 59,
#   'Crime': 36,
#   'Thriller': 53,
#   'Drama': 67,
#   'Romance': 36,
#   'Mystery': 15,
#   'Sci-Fi': 35,
#   'IMAX': 1,
#   'Documentary': 1,
#   'Western': 5,
#   'Film-Noir': 4,
#   'Musical': 6,
#   'Horror': 4,
#   'War': 5},
#  141: {'Mystery': 6,
#   'Thriller': 12,
#   'Crime': 17,
#   'Comedy': 6,
#   'Drama': 23,
#   'Horror': 1,
#   'Action': 6,
#   'Adventure': 4,
#   'War': 3,
#   'Film-Noir': 1,
#   'Sci-Fi': 1,
#   'IMAX': 3,
#   'Fantasy': 1,
#   'Romance': 1},
#  142: {'Adventure': 5,
#   'Children': 1,
#   'Fantasy': 1,
#   'Crime': 4,
#   'Drama': 18,
#   'Romance': 9,
#   'Comedy': 4,
#   'Thriller': 3,
#   'IMAX': 1,
#   'War': 3,
#   'Western': 2,
#   'Horror': 1,
#   'Sci-Fi': 3,
#   'Action': 2},
#  143: {'Adventure': 9,
#   'Animation': 1,
#   'Children': 1,
#   'Comedy': 8,
#   'Fantasy': 2,
#   'Action': 11,
#   'Crime': 4,
#   'Thriller': 13,
#   'Romance': 4,
#   'Sci-Fi': 5,
#   'Drama': 8,
#   'Mystery': 2},
#  144: {'Action': 11,
#   'Crime': 15,
#   'Thriller': 18,
#   'Comedy': 51,
#   'Drama': 28,
#   'Mystery': 5,
#   'Romance': 22,
#   'Musical': 3,
#   'Adventure': 4,
#   'Fantasy': 4,
#   'Film-Noir': 1,
#   'Children': 1,
#   'Western': 1},
#  145: {'Comedy': 3,
#   'Drama': 5,
#   'Film-Noir': 10,
#   'Mystery': 6,
#   'Romance': 4,
#   'Crime': 8,
#   'Musical': 1,
#   'Thriller': 5},
#  146: {'Adventure': 5,
#   'Drama': 3,
#   'IMAX': 1,
#   'Action': 5,
#   'Crime': 2,
#   'Thriller': 4,
#   'Sci-Fi': 2,
#   'Comedy': 2,
#   'Romance': 1,
#   'Animation': 1,
#   'Children': 1,
#   'Musical': 1,
#   'Western': 1},
#  147: {'Adventure': 44,
#   'Animation': 8,
#   'Children': 10,
#   'Comedy': 77,
#   'Fantasy': 26,
#   'Action': 47,
#   'Crime': 34,
#   'Thriller': 37,
#   'Drama': 67,
#   'Romance': 34,
#   'Mystery': 14,
#   'Sci-Fi': 27,
#   'Musical': 10,
#   'Western': 7,
#   'Horror': 8,
#   'War': 6,
#   'Film-Noir': 1,
#   'Documentary': 2,
#   'IMAX': 2},
#  148: {'Comedy': 46,
#   'Romance': 57,
#   'Drama': 27,
#   'War': 1,
#   'Fantasy': 6,
#   'Thriller': 7,
#   'Action': 5,
#   'Adventure': 9,
#   'Mystery': 5,
#   'Crime': 3,
#   'Musical': 5,
#   'Children': 8,
#   'Sci-Fi': 3,
#   'Animation': 7,
#   'Horror': 2},
#  149: {'Adventure': 8,
#   'Animation': 4,
#   'Children': 5,
#   'Comedy': 5,
#   'Fantasy': 5,
#   'Action': 7,
#   'Crime': 2,
#   'Sci-Fi': 4,
#   'Drama': 1,
#   'Musical': 3,
#   'IMAX': 2,
#   'Romance': 2,
#   'Thriller': 3},
#  150: {'Adventure': 5,
#   'Children': 2,
#   'Drama': 10,
#   'Animation': 1,
#   'Musical': 3,
#   'Action': 2,
#   'Comedy': 5,
#   'Crime': 1,
#   'Thriller': 1,
#   'Fantasy': 3,
#   'Sci-Fi': 1},
#  151: {'Comedy': 14,
#   'Action': 16,
#   'Adventure': 14,
#   'Crime': 8,
#   'Sci-Fi': 12,
#   'Drama': 12,
#   'Thriller': 7,
#   'War': 3,
#   'Fantasy': 4,
#   'Horror': 2,
#   'Mystery': 3,
#   'Romance': 5,
#   'Western': 2,
#   'Animation': 2,
#   'Children': 1},
#  152: {'Crime': 19,
#   'Drama': 47,
#   'Comedy': 47,
#   'Romance': 20,
#   'Mystery': 7,
#   'Thriller': 24,
#   'Adventure': 29,
#   'IMAX': 6,
#   'Action': 29,
#   'Sci-Fi': 19,
#   'Animation': 11,
#   'Children': 15,
#   'Musical': 7,
#   'Fantasy': 16,
#   'War': 4,
#   'Horror': 6,
#   'Documentary': 2,
#   'Film-Noir': 1},
#  153: {'Comedy': 37,
#   'Crime': 22,
#   'Thriller': 26,
#   'Drama': 33,
#   'Romance': 18,
#   'Mystery': 6,
#   'Action': 19,
#   'War': 1,
#   'Fantasy': 5,
#   'Adventure': 10,
#   'Sci-Fi': 8,
#   'Western': 1,
#   'Horror': 1,
#   'Children': 3,
#   'Musical': 1,
#   'Film-Noir': 1,
#   'Documentary': 1},
#  154: {'Action': 32,
#   'Crime': 38,
#   'Thriller': 45,
#   'Adventure': 18,
#   'Mystery': 19,
#   'Drama': 67,
#   'IMAX': 4,
#   'Romance': 18,
#   'Western': 2,
#   'Comedy': 48,
#   'War': 5,
#   'Children': 2,
#   'Fantasy': 7,
#   'Musical': 2,
#   'Sci-Fi': 10,
#   'Horror': 5,
#   'Animation': 1,
#   'Documentary': 2,
#   'Film-Noir': 1},
#  155: {'Adventure': 15,
#   'Drama': 14,
#   'Fantasy': 8,
#   'Mystery': 6,
#   'Sci-Fi': 16,
#   'Thriller': 12,
#   'Crime': 8,
#   'Action': 10,
#   'Comedy': 11,
#   'Romance': 5,
#   'Horror': 3,
#   'Animation': 2,
#   'Children': 2,
#   'Documentary': 1},
#  156: {'Adventure': 186,
#   'Animation': 29,
#   'Children': 57,
#   'Comedy': 365,
#   'Fantasy': 89,
#   'Action': 284,
#   'Crime': 182,
#   'Thriller': 362,
#   'Romance': 235,
#   'Drama': 563,
#   'Horror': 118,
#   'Mystery': 113,
#   'Sci-Fi': 139,
#   'War': 72,
#   'IMAX': 4,
#   'Western': 49,
#   'Film-Noir': 17,
#   'Musical': 50},
#  157: {'Crime': 3,
#   'Drama': 31,
#   'Action': 26,
#   'War': 15,
#   'Adventure': 22,
#   'Sci-Fi': 12,
#   'Romance': 15,
#   'Western': 2,
#   'Comedy': 13,
#   'Thriller': 12,
#   'Children': 1,
#   'Fantasy': 4,
#   'Horror': 3,
#   'Musical': 1,
#   'Mystery': 1},
#  158: {'Action': 11,
#   'Crime': 16,
#   'Thriller': 21,
#   'Comedy': 32,
#   'Drama': 47,
#   'Romance': 22,
#   'Mystery': 6,
#   'Sci-Fi': 3,
#   'Children': 9,
#   'Adventure': 8,
#   'Fantasy': 4,
#   'War': 4,
#   'Film-Noir': 1,
#   'Documentary': 1,
#   'Musical': 4,
#   'Horror': 3,
#   'Animation': 4,
#   'Western': 1,
#   'IMAX': 1},
#  159: {'Adventure': 5,
#   'Animation': 6,
#   'Children': 9,
#   'Comedy': 5,
#   'Fantasy': 6,
#   'Drama': 8,
#   'Romance': 3,
#   'Musical': 5,
#   'IMAX': 1,
#   'Action': 5,
#   'Crime': 1,
#   'Thriller': 5,
#   'Sci-Fi': 1,
#   'War': 1,
#   'Mystery': 1},
#  160: {'Adventure': 6,
#   'Animation': 2,
#   'Children': 5,
#   'Comedy': 24,
#   'Fantasy': 4,
#   'Drama': 24,
#   'Romance': 18,
#   'Crime': 7,
#   'Thriller': 16,
#   'Mystery': 2,
#   'IMAX': 1,
#   'War': 3,
#   'Action': 7,
#   'Western': 2,
#   'Sci-Fi': 2,
#   'Horror': 1,
#   'Musical': 1},
#  161: {'Drama': 5,
#   'War': 1,
#   'Adventure': 4,
#   'Western': 2,
#   'Action': 6,
#   'Sci-Fi': 3,
#   'Thriller': 3,
#   'Comedy': 2,
#   'Fantasy': 2,
#   'Horror': 3,
#   'Mystery': 1,
#   'Crime': 1},
#  162: {'Adventure': 40,
#   'Drama': 50,
#   'Fantasy': 19,
#   'Mystery': 14,
#   'Sci-Fi': 32,
#   'Action': 50,
#   'War': 11,
#   'Comedy': 39,
#   'Romance': 12,
#   'Crime': 24,
#   'Thriller': 32,
#   'Animation': 13,
#   'Children': 8,
#   'Musical': 3,
#   'IMAX': 11,
#   'Horror': 6,
#   'Western': 4,
#   'Film-Noir': 2,
#   'Documentary': 2},
#  163: {'Adventure': 10,
#   'Animation': 5,
#   'Children': 3,
#   'Mystery': 10,
#   'Sci-Fi': 14,
#   'Thriller': 16,
#   'Crime': 14,
#   'Drama': 21,
#   'Comedy': 12,
#   'Musical': 1,
#   'IMAX': 6,
#   'War': 2,
#   'Action': 16,
#   'Romance': 6,
#   'Horror': 2,
#   'Fantasy': 1,
#   'Film-Noir': 1,
#   'Western': 1},
#  164: {'Action': 31,
#   'Crime': 16,
#   'Thriller': 22,
#   'Adventure': 12,
#   'Drama': 13,
#   'Comedy': 15,
#   'Romance': 9,
#   'Mystery': 1,
#   'War': 3,
#   'Western': 3,
#   'Sci-Fi': 9,
#   'Horror': 4,
#   'Fantasy': 4,
#   'Children': 3,
#   'Animation': 2,
#   'Musical': 2},
#  165: {'Adventure': 23,
#   'Children': 27,
#   'Fantasy': 9,
#   'Comedy': 28,
#   'Drama': 34,
#   'Romance': 22,
#   'Animation': 9,
#   'Sci-Fi': 2,
#   'Mystery': 5,
#   'Thriller': 14,
#   'Musical': 5,
#   'Crime': 6,
#   'Action': 16,
#   'War': 6,
#   'IMAX': 3,
#   'Western': 5,
#   'Horror': 1},
#  166: {'Adventure': 3,
#   'Drama': 8,
#   'Fantasy': 3,
#   'Mystery': 1,
#   'Sci-Fi': 4,
#   'Documentary': 1,
#   'Animation': 2,
#   'Children': 1,
#   'Musical': 1,
#   'Comedy': 2,
#   'Action': 3,
#   'War': 1,
#   'Thriller': 2,
#   'Romance': 1},
#  167: {'Comedy': 6,
#   'Drama': 10,
#   'Romance': 4,
#   'Action': 8,
#   'Adventure': 13,
#   'Sci-Fi': 7,
#   'Crime': 6,
#   'Animation': 6,
#   'Children': 5,
#   'Musical': 2,
#   'Fantasy': 10,
#   'Thriller': 6,
#   'Mystery': 2,
#   'IMAX': 5,
#   'Horror': 1},
#  168: {'Adventure': 6,
#   'Drama': 25,
#   'Fantasy': 5,
#   'Mystery': 10,
#   'Sci-Fi': 8,
#   'Thriller': 17,
#   'Crime': 19,
#   'Comedy': 20,
#   'Romance': 7,
#   'Horror': 6,
#   'War': 3,
#   'Action': 3,
#   'Film-Noir': 4,
#   'Animation': 2,
#   'Children': 2},
#  169: {'Crime': 4,
#   'Drama': 47,
#   'Action': 4,
#   'War': 7,
#   'Adventure': 14,
#   'Children': 18,
#   'Comedy': 61,
#   'Romance': 22,
#   'Fantasy': 9,
#   'Thriller': 2,
#   'Sci-Fi': 5,
#   'Mystery': 2,
#   'Horror': 1,
#   'Documentary': 1,
#   'Animation': 2,
#   'Musical': 4,
#   'Western': 1},
#  170: {'Crime': 16,
#   'Drama': 40,
#   'Horror': 6,
#   'Mystery': 8,
#   'Thriller': 22,
#   'Sci-Fi': 16,
#   'Action': 9,
#   'Comedy': 24,
#   'Romance': 18,
#   'War': 5,
#   'Film-Noir': 4,
#   'Fantasy': 15,
#   'Adventure': 14,
#   'Children': 8,
#   'Musical': 6,
#   'Documentary': 1,
#   'Animation': 3},
#  171: {'Comedy': 7,
#   'Drama': 7,
#   'Romance': 1,
#   'War': 1,
#   'Action': 6,
#   'Adventure': 3,
#   'Sci-Fi': 7,
#   'Thriller': 6,
#   'Crime': 1,
#   'Horror': 5,
#   'Fantasy': 1},
#  172: {'Adventure': 4,
#   'Animation': 1,
#   'Children': 2,
#   'Comedy': 1,
#   'Fantasy': 1,
#   'Drama': 6,
#   'Thriller': 1,
#   'War': 1,
#   'Action': 1,
#   'Sci-Fi': 2,
#   'Crime': 1,
#   'Western': 1},
#  173: {'Mystery': 8,
#   'Thriller': 8,
#   'Comedy': 4,
#   'Crime': 4,
#   'Drama': 10,
#   'Fantasy': 3,
#   'Film-Noir': 2,
#   'Romance': 6,
#   'Sci-Fi': 4,
#   'Action': 3,
#   'Adventure': 2,
#   'Animation': 1,
#   'Children': 1},
#  174: {'Children': 4,
#   'Comedy': 5,
#   'Fantasy': 4,
#   'Action': 7,
#   'Romance': 5,
#   'War': 3,
#   'Western': 1,
#   'Adventure': 5,
#   'Crime': 2,
#   'Drama': 9,
#   'Sci-Fi': 1,
#   'Animation': 2,
#   'Musical': 2,
#   'Mystery': 1},
#  175: {'Crime': 12,
#   'Mystery': 4,
#   'Thriller': 9,
#   'Adventure': 5,
#   'Drama': 26,
#   'IMAX': 1,
#   'Comedy': 12,
#   'Romance': 7,
#   'War': 4,
#   'Film-Noir': 2,
#   'Children': 2,
#   'Fantasy': 2,
#   'Musical': 1,
#   'Action': 5,
#   'Western': 1,
#   'Sci-Fi': 1},
#  176: {'Animation': 1,
#   'Children': 2,
#   'Drama': 10,
#   'Fantasy': 8,
#   'Musical': 2,
#   'Comedy': 5,
#   'Romance': 11,
#   'Adventure': 7,
#   'Action': 1,
#   'IMAX': 3,
#   'Thriller': 1,
#   'Mystery': 1},
#  177: {'Comedy': 4,
#   'Drama': 6,
#   'Romance': 5,
#   'War': 2,
#   'Action': 5,
#   'Adventure': 3,
#   'Sci-Fi': 1,
#   'Thriller': 2,
#   'Crime': 2,
#   'Horror': 1,
#   'Musical': 2,
#   'Children': 1,
#   'Fantasy': 2,
#   'Mystery': 1},
#  178: {'Comedy': 12,
#   'Drama': 12,
#   'Romance': 9,
#   'War': 4,
#   'Musical': 10,
#   'Mystery': 4,
#   'Thriller': 4,
#   'Film-Noir': 3,
#   'Adventure': 1,
#   'Children': 3,
#   'Fantasy': 3,
#   'Animation': 1},
#  179: {'Animation': 3,
#   'Children': 3,
#   'Drama': 3,
#   'Musical': 3,
#   'Romance': 5,
#   'Comedy': 5,
#   'Fantasy': 6,
#   'Action': 5,
#   'Horror': 4,
#   'Sci-Fi': 2,
#   'Thriller': 3,
#   'Mystery': 2,
#   'Adventure': 4,
#   'Crime': 1},
#  180: {'Comedy': 6,
#   'Crime': 3,
#   'Drama': 6,
#   'Thriller': 5,
#   'Action': 8,
#   'Sci-Fi': 1,
#   'Adventure': 7,
#   'Fantasy': 3,
#   'Horror': 1,
#   'Animation': 2,
#   'Children': 2,
#   'Romance': 1,
#   'Mystery': 1,
#   'IMAX': 1},
#  181: {'Mystery': 2,
#   'Sci-Fi': 7,
#   'Thriller': 2,
#   'Comedy': 4,
#   'Drama': 6,
#   'Romance': 5,
#   'Musical': 2,
#   'Adventure': 2,
#   'Animation': 1,
#   'Children': 2,
#   'Fantasy': 1,
#   'Horror': 2,
#   'Action': 4,
#   'War': 1,
#   'Western': 2,
#   'Crime': 1,
#   'IMAX': 1},
#  182: {'Comedy': 10,
#   'Action': 33,
#   'Fantasy': 6,
#   'Horror': 4,
#   'Western': 1,
#   'Drama': 16,
#   'Romance': 2,
#   'Adventure': 10,
#   'Thriller': 16,
#   'War': 5,
#   'Mystery': 2,
#   'Crime': 11,
#   'Animation': 1,
#   'Sci-Fi': 11,
#   'IMAX': 8,
#   'Film-Noir': 1},
#  183: {'Action': 13,
#   'Comedy': 5,
#   'Crime': 6,
#   'Drama': 4,
#   'Thriller': 12,
#   'Adventure': 7,
#   'Sci-Fi': 4,
#   'Romance': 1},
#  184: {'Comedy': 29,
#   'Romance': 26,
#   'Action': 19,
#   'Crime': 11,
#   'Thriller': 28,
#   'Adventure': 12,
#   'Drama': 56,
#   'Horror': 4,
#   'Mystery': 6,
#   'Sci-Fi': 6,
#   'Children': 5,
#   'War': 5,
#   'IMAX': 1,
#   'Western': 3,
#   'Fantasy': 3,
#   'Animation': 1,
#   'Musical': 1},
#  185: {'Adventure': 4,
#   'Drama': 5,
#   'IMAX': 1,
#   'Comedy': 6,
#   'Crime': 3,
#   'Thriller': 5,
#   'Romance': 3,
#   'War': 1,
#   'Action': 5,
#   'Sci-Fi': 4,
#   'Horror': 1},
#  186: {'Adventure': 6,
#   'Animation': 2,
#   'Children': 6,
#   'Comedy': 18,
#   'Fantasy': 4,
#   'Drama': 15,
#   'Romance': 7,
#   'Action': 2,
#   'Sci-Fi': 4,
#   'War': 2,
#   'Thriller': 2,
#   'Documentary': 1,
#   'Musical': 2,
#   'Crime': 1},
#  187: {'Adventure': 1,
#   'Drama': 4,
#   'IMAX': 1,
#   'Comedy': 2,
#   'Romance': 1,
#   'War': 1,
#   'Crime': 1,
#   'Horror': 2,
#   'Thriller': 2,
#   'Fantasy': 1,
#   'Sci-Fi': 2,
#   'Mystery': 1,
#   'Documentary': 1,
#   'Western': 1},
#  188: {'Adventure': 14,
#   'Animation': 3,
#   'Children': 5,
#   'Comedy': 22,
#   'Fantasy': 3,
#   'Action': 17,
#   'Crime': 7,
#   'Thriller': 20,
#   'Drama': 23,
#   'Romance': 15,
#   'Mystery': 3,
#   'War': 5,
#   'IMAX': 2,
#   'Sci-Fi': 3,
#   'Musical': 2,
#   'Western': 3},
#  189: {'Adventure': 38,
#   'Animation': 17,
#   'Children': 20,
#   'Comedy': 45,
#   'Fantasy': 26,
#   'Drama': 35,
#   'Musical': 9,
#   'Romance': 20,
#   'Action': 30,
#   'Horror': 9,
#   'Thriller': 25,
#   'War': 6,
#   'Sci-Fi': 18,
#   'Crime': 12,
#   'Western': 1,
#   'Mystery': 7,
#   'IMAX': 11},
#  190: {'Mystery': 3,
#   'Sci-Fi': 9,
#   'Thriller': 6,
#   'Action': 12,
#   'Adventure': 11,
#   'Crime': 4,
#   'Drama': 26,
#   'Comedy': 16,
#   'Fantasy': 3,
#   'Romance': 12,
#   'War': 3,
#   'Animation': 2,
#   'Children': 1},
#  191: {'Crime': 3,
#   'Mystery': 4,
#   'Thriller': 3,
#   'Drama': 4,
#   'War': 2,
#   'Comedy': 8,
#   'Sci-Fi': 2,
#   'Fantasy': 2,
#   'Adventure': 1,
#   'Action': 1,
#   'Romance': 1},
#  192: {'Adventure': 16,
#   'Comedy': 21,
#   'Crime': 8,
#   'Romance': 7,
#   'Action': 19,
#   'Drama': 15,
#   'Thriller': 14,
#   'Horror': 7,
#   'Sci-Fi': 8,
#   'Children': 4,
#   'Fantasy': 4,
#   'Western': 1,
#   'Mystery': 2,
#   'Animation': 3,
#   'Musical': 2},
#  193: {'Adventure': 2,
#   'Drama': 6,
#   'War': 3,
#   'Comedy': 2,
#   'Romance': 2,
#   'Action': 4,
#   'Thriller': 2,
#   'Crime': 1},
#  194: {'Action': 9,
#   'Adventure': 13,
#   'Sci-Fi': 8,
#   'Comedy': 6,
#   'Thriller': 2,
#   'Children': 4,
#   'Fantasy': 7,
#   'Musical': 3,
#   'Drama': 2,
#   'Romance': 3,
#   'Animation': 3,
#   'Crime': 2,
#   'IMAX': 1,
#   'Mystery': 1},
#  195: {'Comedy': 20,
#   'Horror': 7,
#   'Thriller': 11,
#   'Drama': 20,
#   'Action': 9,
#   'Adventure': 7,
#   'Sci-Fi': 6,
#   'Animation': 4,
#   'Children': 3,
#   'Romance': 4,
#   'Crime': 5,
#   'Fantasy': 5,
#   'Musical': 1,
#   'Mystery': 4,
#   'War': 1},
#  196: {'Action': 18,
#   'Crime': 9,
#   'Thriller': 7,
#   'Drama': 14,
#   'Musical': 4,
#   'Romance': 8,
#   'Adventure': 20,
#   'Sci-Fi': 5,
#   'Comedy': 26,
#   'Fantasy': 16,
#   'Horror': 9,
#   'Children': 10,
#   'Animation': 5,
#   'Mystery': 2,
#   'Western': 1},
#  197: {'Crime': 9,
#   'Mystery': 2,
#   'Thriller': 5,
#   'Action': 7,
#   'Drama': 9,
#   'War': 1,
#   'Comedy': 4,
#   'Adventure': 1,
#   'IMAX': 2,
#   'Sci-Fi': 1},
#  198: {'Crime': 8,
#   'Mystery': 5,
#   'Thriller': 10,
#   'Action': 3,
#   'Drama': 10,
#   'Comedy': 3,
#   'Adventure': 2,
#   'Fantasy': 3,
#   'Romance': 3,
#   'Film-Noir': 1,
#   'Sci-Fi': 1},
#  199: {'Adventure': 1,
#   'Animation': 1,
#   'Children': 1,
#   'Comedy': 5,
#   'Fantasy': 1,
#   'Drama': 8,
#   'Romance': 3,
#   'Documentary': 3,
#   'Mystery': 1,
#   'Western': 1,
#   'Crime': 1,
#   'Thriller': 1},
#  200: {'Action': 17,
#   'Crime': 10,
#   'Thriller': 18,
#   'Drama': 19,
#   'Romance': 10,
#   'Comedy': 15,
#   'Mystery': 1,
#   'Sci-Fi': 4,
#   'War': 6,
#   'Adventure': 6,
#   'IMAX': 3,
#   'Western': 3,
#   'Horror': 4,
#   'Fantasy': 3,
#   'Animation': 3,
#   'Children': 3,
#   'Musical': 3},
#  201: {'Adventure': 4,
#   'Drama': 46,
#   'Fantasy': 9,
#   'Mystery': 12,
#   'Sci-Fi': 6,
#   'Crime': 10,
#   'Thriller': 14,
#   'Romance': 16,
#   'Comedy': 11,
#   'Action': 2,
#   'War': 3,
#   'Animation': 4,
#   'Horror': 1,
#   'Film-Noir': 2,
#   'Musical': 4,
#   'Documentary': 2},
# ...
#   'Documentary': 3},
#  936: {'Adventure': 22,
#   'Animation': 10,
#   'Children': 15,
#   'Comedy': 57,
#   'Fantasy': 15,
#   'Crime': 21,
#   'Thriller': 24,
#   'Drama': 42,
#   'Romance': 24,
#   'War': 7,
#   'Mystery': 6,
#   'Action': 18,
#   'Sci-Fi': 11,
#   'Musical': 10,
#   'Horror': 4,
#   'Western': 1,
#   'Film-Noir': 1,
#   'Documentary': 1},
#  937: {'Crime': 23,
#   'Mystery': 8,
#   'Thriller': 22,
#   'Action': 18,
#   'Adventure': 5,
#   'Comedy': 13,
#   'Drama': 21,
#   'Sci-Fi': 5,
#   'Horror': 1,
#   'Romance': 3,
#   'Film-Noir': 1,
#   'IMAX': 4,
#   'Fantasy': 1,
#   'War': 2,
#   'Animation': 1,
#   'Children': 1},
#  938: {'Crime': 4,
#   'Horror': 2,
#   'Thriller': 1,
#   'Adventure': 3,
#   'Animation': 1,
#   'Children': 2,
#   'Fantasy': 1,
#   'Musical': 2,
#   'Drama': 10,
#   'Action': 3,
#   'Sci-Fi': 2,
#   'Romance': 3,
#   'Mystery': 1,
#   'Comedy': 4},
#  939: {'Adventure': 7,
#   'Children': 1,
#   'Fantasy': 1,
#   'Action': 8,
#   'Drama': 11,
#   'War': 4,
#   'IMAX': 1,
#   'Comedy': 3,
#   'Crime': 3,
#   'Thriller': 6,
#   'Sci-Fi': 4,
#   'Romance': 2,
#   'Western': 2},
#  940: {'Adventure': 10,
#   'Drama': 118,
#   'Fantasy': 11,
#   'Mystery': 17,
#   'Sci-Fi': 10,
#   'Romance': 36,
#   'Comedy': 64,
#   'Documentary': 47,
#   'Crime': 30,
#   'Thriller': 29,
#   'Film-Noir': 1,
#   'Action': 9,
#   'Horror': 6,
#   'Western': 1,
#   'Musical': 3,
#   'Animation': 2,
#   'War': 5,
#   'Children': 1},
#  941: {'Adventure': 32,
#   'Animation': 3,
#   'Children': 6,
#   'Comedy': 50,
#   'Fantasy': 12,
#   'Action': 67,
#   'Crime': 56,
#   'Thriller': 92,
#   'Drama': 75,
#   'Romance': 37,
#   'Mystery': 26,
#   'Horror': 14,
#   'War': 13,
#   'Film-Noir': 9,
#   'Western': 8,
#   'Sci-Fi': 34,
#   'Documentary': 1,
#   'Musical': 1},
#  942: {'Action': 9,
#   'Adventure': 4,
#   'Thriller': 11,
#   'Mystery': 2,
#   'Sci-Fi': 5,
#   'Crime': 4,
#   'Drama': 3,
#   'Horror': 2,
#   'Comedy': 4,
#   'Romance': 3,
#   'Fantasy': 1},
#  943: {'Drama': 42,
#   'Romance': 16,
#   'Mystery': 4,
#   'Sci-Fi': 7,
#   'Thriller': 12,
#   'Crime': 14,
#   'Comedy': 16,
#   'Action': 10,
#   'War': 9,
#   'Adventure': 6,
#   'Horror': 1,
#   'Children': 1,
#   'Western': 1,
#   'Fantasy': 1},
#  944: {'Drama': 4,
#   'War': 3,
#   'Comedy': 5,
#   'Action': 2,
#   'Adventure': 1,
#   'Fantasy': 1,
#   'Thriller': 3,
#   'Horror': 2,
#   'Mystery': 1,
#   'Crime': 1,
#   'Children': 1},
#  945: {'Mystery': 3,
#   'Sci-Fi': 8,
#   'Thriller': 15,
#   'Children': 2,
#   'Drama': 22,
#   'Crime': 11,
#   'Action': 12,
#   'War': 6,
#   'Adventure': 7,
#   'Comedy': 15,
#   'Romance': 6,
#   'Horror': 1,
#   'Fantasy': 1},
#  946: {'Crime': 9,
#   'Drama': 8,
#   'Horror': 1,
#   'Mystery': 3,
#   'Thriller': 4,
#   'Action': 3,
#   'Comedy': 2,
#   'Romance': 1},
#  947: {'Drama': 76,
#   'Romance': 29,
#   'Crime': 15,
#   'Thriller': 25,
#   'Documentary': 1,
#   'Comedy': 37,
#   'War': 13,
#   'Action': 12,
#   'Sci-Fi': 7,
#   'Adventure': 16,
#   'Western': 9,
#   'Animation': 1,
#   'Children': 3,
#   'Mystery': 17,
#   'Film-Noir': 8,
#   'Fantasy': 8,
#   'Musical': 5,
#   'Horror': 11},
#  948: {'Drama': 19,
#   'Romance': 11,
#   'Crime': 11,
#   'War': 3,
#   'Action': 28,
#   'Sci-Fi': 16,
#   'Thriller': 20,
#   'Adventure': 31,
#   'Animation': 7,
#   'Children': 9,
#   'Comedy': 9,
#   'Fantasy': 19,
#   'Mystery': 11,
#   'IMAX': 16,
#   'Musical': 1},
#  949: {'Adventure': 18,
#   'Animation': 18,
#   'Children': 6,
#   'Comedy': 10,
#   'Fantasy': 18,
#   'Drama': 36,
#   'Mystery': 11,
#   'Sci-Fi': 23,
#   'Thriller': 18,
#   'Action': 9,
#   'Crime': 5,
#   'Horror': 7,
#   'War': 3,
#   'Film-Noir': 1,
#   'Romance': 12,
#   'IMAX': 2,
#   'Musical': 1},
#  950: {'Adventure': 15,
#   'Drama': 62,
#   'Fantasy': 9,
#   'Mystery': 7,
#   'Sci-Fi': 18,
#   'Crime': 14,
#   'Thriller': 19,
#   'Comedy': 21,
#   'Romance': 12,
#   'Action': 10,
#   'Animation': 3,
#   'War': 4,
#   'Horror': 4,
#   'Film-Noir': 2,
#   'Western': 1,
#   'Musical': 3,
#   'Documentary': 1,
#   'Children': 2},
#  951: {'Mystery': 21,
#   'Thriller': 87,
#   'Crime': 52,
#   'Action': 108,
#   'Comedy': 49,
#   'Horror': 24,
#   'Drama': 66,
#   'Romance': 16,
#   'Western': 5,
#   'Fantasy': 27,
#   'War': 17,
#   'Sci-Fi': 36,
#   'Adventure': 56,
#   'Animation': 6,
#   'Children': 3,
#   'Film-Noir': 2,
#   'IMAX': 5,
#   'Musical': 1},
#  952: {'Adventure': 8,
#   'Animation': 1,
#   'Children': 2,
#   'Comedy': 14,
#   'Fantasy': 3,
#   'Action': 15,
#   'Sci-Fi': 6,
#   'Crime': 6,
#   'Drama': 5,
#   'Thriller': 4,
#   'Romance': 5,
#   'War': 1,
#   'Musical': 1},
#  953: {'Comedy': 19,
#   'Action': 17,
#   'Horror': 3,
#   'Thriller': 13,
#   'Drama': 12,
#   'War': 2,
#   'Crime': 13,
#   'Adventure': 10,
#   'Romance': 6,
#   'Fantasy': 4,
#   'Mystery': 3,
#   'Sci-Fi': 3,
#   'Animation': 3,
#   'Children': 2,
#   'IMAX': 1,
#   'Musical': 1},
#  954: {'Action': 20,
#   'Adventure': 14,
#   'Thriller': 18,
#   'Children': 2,
#   'Drama': 11,
#   'War': 3,
#   'IMAX': 1,
#   'Comedy': 12,
#   'Crime': 5,
#   'Fantasy': 5,
#   'Horror': 1,
#   'Mystery': 1,
#   'Sci-Fi': 6,
#   'Romance': 7,
#   'Western': 1,
#   'Animation': 1,
#   'Musical': 1},
#  955: {'Adventure': 63,
#   'Animation': 7,
#   'Children': 12,
#   'Comedy': 210,
#   'Fantasy': 34,
#   'Action': 96,
#   'Crime': 71,
#   'Thriller': 129,
#   'Romance': 97,
#   'Drama': 219,
#   'War': 30,
#   'Mystery': 45,
#   'Horror': 43,
#   'IMAX': 1,
#   'Sci-Fi': 57,
#   'Documentary': 7,
#   'Musical': 10,
#   'Film-Noir': 6,
#   'Western': 9},
#  956: {'Drama': 17,
#   'Children': 3,
#   'Action': 8,
#   'Adventure': 6,
#   'Thriller': 8,
#   'Romance': 8,
#   'IMAX': 2,
#   'War': 5,
#   'Comedy': 5,
#   'Crime': 6,
#   'Western': 2,
#   'Animation': 2,
#   'Musical': 2,
#   'Horror': 1,
#   'Fantasy': 1},
#  957: {'Documentary': 9, 'Adventure': 1},
#  958: {'Action': 4,
#   'Adventure': 3,
#   'Animation': 1,
#   'Horror': 1,
#   'Sci-Fi': 1,
#   'Drama': 5,
#   'Comedy': 3,
#   'Crime': 2,
#   'Romance': 2,
#   'Thriller': 3,
#   'Fantasy': 2},
#  959: {'Mystery': 3,
#   'Sci-Fi': 4,
#   'Thriller': 8,
#   'Action': 6,
#   'Crime': 9,
#   'Drama': 11,
#   'Adventure': 4,
#   'Comedy': 7,
#   'Romance': 6,
#   'Western': 1,
#   'Film-Noir': 1,
#   'War': 2,
#   'Horror': 1},
#  960: {'Comedy': 13,
#   'Drama': 19,
#   'Romance': 12,
#   'Crime': 5,
#   'Thriller': 11,
#   'Children': 2,
#   'Action': 12,
#   'Adventure': 8,
#   'Fantasy': 5,
#   'Mystery': 1,
#   'IMAX': 2,
#   'War': 3,
#   'Sci-Fi': 8,
#   'Horror': 1,
#   'Western': 1,
#   'Animation': 1,
#   'Musical': 1},
#  961: {'Drama': 6,
#   'Romance': 3,
#   'Mystery': 1,
#   'Sci-Fi': 2,
#   'Thriller': 2,
#   'Crime': 3,
#   'Comedy': 2,
#   'Action': 1,
#   'Adventure': 1,
#   'War': 1},
#  962: {'Action': 8,
#   'Comedy': 18,
#   'Romance': 8,
#   'Adventure': 15,
#   'Crime': 2,
#   'Drama': 6,
#   'Mystery': 1,
#   'Thriller': 5,
#   'Fantasy': 11,
#   'Horror': 1,
#   'Sci-Fi': 2,
#   'Animation': 4,
#   'Children': 5,
#   'Musical': 2,
#   'IMAX': 2,
#   'Documentary': 2},
#  963: {'Adventure': 3,
#   'Animation': 1,
#   'Children': 1,
#   'Comedy': 6,
#   'Fantasy': 1,
#   'Action': 2,
#   'Crime': 1,
#   'Drama': 5,
#   'Thriller': 2,
#   'IMAX': 1,
#   'Romance': 1,
#   'Sci-Fi': 2,
#   'Western': 1},
#  964: {'Action': 67,
#   'Crime': 17,
#   'Thriller': 30,
#   'Adventure': 58,
#   'Sci-Fi': 31,
#   'Animation': 21,
#   'Children': 18,
#   'Fantasy': 21,
#   'Musical': 7,
#   'Romance': 9,
#   'IMAX': 21,
#   'Mystery': 6,
#   'Comedy': 22,
#   'Drama': 15,
#   'Horror': 1,
#   'War': 4,
#   'Documentary': 1},
#  965: {'Mystery': 7,
#   'Sci-Fi': 9,
#   'Thriller': 19,
#   'Crime': 17,
#   'Comedy': 12,
#   'Action': 12,
#   'Drama': 28,
#   'War': 3,
#   'Adventure': 9,
#   'Romance': 8,
#   'Horror': 1,
#   'Fantasy': 5,
#   'Documentary': 1},
#  966: {'Adventure': 5,
#   'Drama': 8,
#   'IMAX': 2,
#   'Horror': 4,
#   'Sci-Fi': 4,
#   'Comedy': 4,
#   'Crime': 4,
#   'Thriller': 5,
#   'Action': 2,
#   'Animation': 2,
#   'Children': 2,
#   'Musical': 2,
#   'Western': 1,
#   'Fantasy': 1,
#   'Romance': 1},
#  967: {'Comedy': 31,
#   'Crime': 3,
#   'Thriller': 8,
#   'Drama': 16,
#   'Romance': 13,
#   'Action': 12,
#   'Horror': 1,
#   'War': 3,
#   'Adventure': 9,
#   'Sci-Fi': 6,
#   'Fantasy': 6,
#   'Animation': 2,
#   'Children': 2,
#   'Western': 1},
#  968: {'Action': 13,
#   'Crime': 14,
#   'Thriller': 11,
#   'Mystery': 4,
#   'Comedy': 15,
#   'Horror': 1,
#   'Animation': 2,
#   'Sci-Fi': 4,
#   'Drama': 19,
#   'Romance': 9,
#   'Musical': 1,
#   'Adventure': 7,
#   'Western': 1,
#   'Children': 1,
#   'Fantasy': 4,
#   'War': 1},
#  969: {'Adventure': 34,
#   'Animation': 8,
#   'Children': 6,
#   'Comedy': 63,
#   'Fantasy': 25,
#   'Action': 60,
#   'Crime': 85,
#   'Thriller': 109,
#   'Drama': 167,
#   'Mystery': 48,
#   'Sci-Fi': 49,
#   'Musical': 2,
#   'War': 15,
#   'Horror': 48,
#   'Romance': 28,
#   'Western': 10,
#   'Film-Noir': 8,
#   'IMAX': 7},
#  970: {'Crime': 27,
#   'Drama': 114,
#   'Romance': 25,
#   'Mystery': 13,
#   'Sci-Fi': 37,
#   'Thriller': 57,
#   'War': 33,
#   'Action': 71,
#   'Adventure': 50,
#   'IMAX': 1,
#   'Comedy': 52,
#   'Documentary': 2,
#   'Fantasy': 16,
#   'Animation': 2,
#   'Children': 5,
#   'Musical': 9,
#   'Western': 6,
#   'Horror': 22},
#  971: {'Action': 135,
#   'Crime': 128,
#   'Thriller': 165,
#   'Drama': 313,
#   'Comedy': 223,
#   'Mystery': 62,
#   'Sci-Fi': 85,
#   'Horror': 55,
#   'Romance': 79,
#   'Adventure': 97,
#   'War': 43,
#   'Western': 12,
#   'Fantasy': 51,
#   'Children': 17,
#   'Animation': 11,
#   'Musical': 17,
#   'Film-Noir': 12,
#   'Documentary': 7,
#   'IMAX': 3},
#  972: {'Adventure': 3,
#   'Animation': 1,
#   'Children': 1,
#   'Comedy': 5,
#   'Fantasy': 1,
#   'Action': 3,
#   'Crime': 1,
#   'Thriller': 4,
#   'Drama': 4,
#   'Romance': 3,
#   'Mystery': 1,
#   'Sci-Fi': 3},
#  973: {'Action': 5,
#   'Comedy': 5,
#   'Romance': 11,
#   'Animation': 7,
#   'Children': 6,
#   'Fantasy': 9,
#   'Musical': 7,
#   'IMAX': 2,
#   'Drama': 12,
#   'Mystery': 2,
#   'Thriller': 2,
#   'War': 1,
#   'Adventure': 6,
#   'Crime': 1,
#   'Sci-Fi': 1},
#  974: {'Mystery': 2,
#   'Thriller': 7,
#   'Crime': 4,
#   'Action': 6,
#   'Drama': 12,
#   'War': 3,
#   'Adventure': 5,
#   'Sci-Fi': 4,
#   'Comedy': 6,
#   'Romance': 2,
#   'Horror': 1,
#   'Musical': 2,
#   'Documentary': 1,
#   'Fantasy': 1},
#  975: {'Mystery': 16,
#   'Sci-Fi': 17,
#   'Thriller': 38,
#   'Crime': 30,
#   'Action': 22,
#   'Drama': 80,
#   'Comedy': 39,
#   'Romance': 17,
#   'War': 9,
#   'Fantasy': 7,
#   'Adventure': 14,
#   'Horror': 3,
#   'Western': 4,
#   'Documentary': 6,
#   'Film-Noir': 4,
#   'Animation': 2,
#   'Children': 1,
#   'IMAX': 1},
#  976: {'Action': 9,
#   'Adventure': 6,
#   'Thriller': 6,
#   'Sci-Fi': 8,
#   'Crime': 4,
#   'Drama': 5,
#   'Horror': 2,
#   'Comedy': 2,
#   'Romance': 1,
#   'Animation': 1,
#   'Fantasy': 2,
#   'Mystery': 2,
#   'IMAX': 1},
#  977: {'Drama': 10,
#   'Romance': 9,
#   'Mystery': 1,
#   'Sci-Fi': 1,
#   'Thriller': 3,
#   'Crime': 3,
#   'War': 1,
#   'Comedy': 6,
#   'Fantasy': 3,
#   'Horror': 1,
#   'Animation': 2,
#   'Children': 2,
#   'Musical': 2,
#   'IMAX': 1},
#  978: {'Comedy': 77,
#   'Romance': 63,
#   'Crime': 8,
#   'Thriller': 13,
#   'Drama': 31,
#   'Action': 16,
#   'Horror': 1,
#   'Adventure': 14,
#   'Sci-Fi': 7,
#   'Fantasy': 7,
#   'Children': 5,
#   'Animation': 4,
#   'Musical': 8,
#   'Mystery': 4,
#   'War': 2,
#   'Film-Noir': 1,
#   'Western': 1},
#  979: {'Mystery': 4,
#   'Sci-Fi': 16,
#   'Thriller': 26,
#   'Action': 38,
#   'Drama': 29,
#   'War': 8,
#   'Comedy': 23,
#   'Crime': 20,
#   'Romance': 3,
#   'Western': 1,
#   'Adventure': 26,
#   'Horror': 1,
#   'Fantasy': 9,
#   'Documentary': 6,
#   'Film-Noir': 1,
#   'IMAX': 14},
#  980: {'Adventure': 11,
#   'Children': 4,
#   'Fantasy': 2,
#   'Drama': 16,
#   'Action': 9,
#   'Thriller': 13,
#   'War': 4,
#   'IMAX': 2,
#   'Crime': 3,
#   'Comedy': 8,
#   'Sci-Fi': 3,
#   'Romance': 5,
#   'Animation': 2,
#   'Musical': 2,
#   'Western': 3},
#  981: {'Action': 11,
#   'Crime': 6,
#   'Drama': 11,
#   'Thriller': 7,
#   'Adventure': 7,
#   'Sci-Fi': 3,
#   'War': 7,
#   'Animation': 1,
#   'Children': 1,
#   'Comedy': 7,
#   'Musical': 1,
#   'Horror': 2,
#   'Romance': 4,
#   'Mystery': 2,
#   'Fantasy': 1},
#  982: {'Action': 220,
#   'Crime': 201,
#   'Thriller': 294,
#   'Drama': 561,
#   'Comedy': 307,
#   'Romance': 144,
#   'Adventure': 125,
#   'Fantasy': 77,
#   'Mystery': 122,
#   'Sci-Fi': 97,
#   'Horror': 186,
#   'Documentary': 11,
#   'Western': 29,
#   'Film-Noir': 16,
#   'Animation': 50,
#   'Children': 45,
#   'Musical': 30,
#   'IMAX': 11,
#   'War': 56},
#  983: {'Crime': 6,
#   'Drama': 12,
#   'Comedy': 9,
#   'Action': 8,
#   'Adventure': 8,
#   'Thriller': 14,
#   'Mystery': 2,
#   'Sci-Fi': 2,
#   'Fantasy': 1,
#   'Romance': 5},
#  984: {'Adventure': 48,
#   'Animation': 9,
#   'Children': 10,
#   'Comedy': 46,
#   'Fantasy': 14,
#   'Romance': 23,
#   'Crime': 17,
#   'Thriller': 34,
#   'Mystery': 8,
#   'Sci-Fi': 27,
#   'Action': 52,
#   'Drama': 37,
#   'War': 7,
#   'Horror': 6,
#   'Musical': 2,
#   'IMAX': 4,
#   'Western': 4},
#  985: {'Crime': 4,
#   'Drama': 13,
#   'Action': 7,
#   'Sci-Fi': 3,
#   'Thriller': 7,
#   'Comedy': 8,
#   'War': 1,
#   'Mystery': 4,
#   'Romance': 6,
#   'Adventure': 7,
#   'Film-Noir': 1,
#   'Animation': 2,
#   'Children': 1,
#   'Fantasy': 8,
#   'Horror': 2,
#   'Musical': 2,
#   'IMAX': 1},
#  986: {'Adventure': 12,
#   'Animation': 3,
#   'Children': 4,
#   'Comedy': 33,
#   'Fantasy': 5,
#   'Action': 16,
#   'Thriller': 33,
#   'Crime': 27,
#   'Drama': 76,
#   'Romance': 28,
#   'Horror': 4,
#   'Mystery': 9,
#   'Sci-Fi': 6,
#   'War': 4,
#   'Musical': 1,
#   'IMAX': 1,
#   'Western': 4,
#   'Film-Noir': 2},
#  987: {'Adventure': 26,
#   'Animation': 4,
#   'Children': 9,
#   'Comedy': 36,
#   'Fantasy': 14,
#   'Crime': 22,
#   'Drama': 62,
#   'Romance': 16,
#   'Mystery': 6,
#   'Sci-Fi': 29,
#   'Thriller': 25,
#   'Action': 38,
#   'War': 17,
#   'Western': 4,
#   'Horror': 6,
#   'Musical': 4},
#  988: {'Crime': 7,
#   'Mystery': 3,
#   'Thriller': 11,
#   'Action': 10,
#   'Adventure': 9,
#   'Sci-Fi': 8,
#   'Comedy': 6,
#   'Drama': 8,
#   'Horror': 4,
#   'Animation': 2,
#   'Children': 2,
#   'Film-Noir': 1,
#   'Romance': 3,
#   'Fantasy': 6,
#   'War': 1,
#   'IMAX': 1},
#  989: {'Adventure': 32,
#   'Animation': 15,
#   'Children': 25,
#   'Comedy': 77,
#   'Fantasy': 24,
#   'Drama': 52,
#   'Mystery': 8,
#   'Thriller': 26,
#   'War': 8,
#   'Romance': 32,
#   'Sci-Fi': 16,
#   'Action': 27,
#   'Horror': 8,
#   'Musical': 14,
#   'Crime': 23,
#   'Western': 1,
#   'IMAX': 2,
#   'Documentary': 1},
#  990: {'Mystery': 1,
#   'Sci-Fi': 11,
#   'Thriller': 8,
#   'Action': 18,
#   'Adventure': 20,
#   'Comedy': 11,
#   'Crime': 6,
#   'Drama': 15,
#   'Romance': 9,
#   'War': 1,
#   'Animation': 7,
#   'Children': 7,
#   'Musical': 4,
#   'IMAX': 7,
#   'Horror': 1,
#   'Fantasy': 11},
#  991: {'Crime': 3,
#   'Mystery': 5,
#   'Thriller': 8,
#   'Drama': 6,
#   'War': 1,
#   'Romance': 4,
#   'Comedy': 7,
#   'Action': 6,
#   'Adventure': 3,
#   'Horror': 2,
#   'Sci-Fi': 7,
#   'Fantasy': 3},
#  992: {'Drama': 10,
#   'War': 2,
#   'Thriller': 3,
#   'Comedy': 3,
#   'Crime': 2,
#   'Documentary': 1,
#   'Action': 1,
#   'IMAX': 1},
#  993: {'Comedy': 43,
#   'Crime': 3,
#   'Thriller': 2,
#   'Romance': 13,
#   'Drama': 16,
#   'Mystery': 2,
#   'War': 2,
#   'Children': 2,
#   'Fantasy': 7,
#   'Musical': 3,
#   'Adventure': 2,
#   'Action': 3,
#   'Sci-Fi': 2,
#   'Horror': 1,
#   'Western': 1},
#  994: {'Mystery': 12,
#   'Sci-Fi': 14,
#   'Thriller': 29,
#   'Action': 24,
#   'Drama': 106,
#   'War': 11,
#   'Crime': 14,
#   'Horror': 2,
#   'Romance': 34,
#   'Adventure': 22,
#   'Comedy': 36,
#   'Fantasy': 9,
#   'Film-Noir': 1,
#   'Children': 2,
#   'Musical': 3,
#   'Documentary': 4,
#   'IMAX': 1,
#   'Animation': 1},
#  995: {'Action': 72,
#   'Adventure': 61,
#   'Thriller': 54,
#   'Mystery': 15,
#   'Crime': 18,
#   'Drama': 41,
#   'Comedy': 62,
#   'Sci-Fi': 64,
#   'Horror': 19,
#   'Fantasy': 38,
#   'Animation': 35,
#   'Children': 16,
#   'Musical': 8,
#   'IMAX': 7,
#   'Romance': 16,
#   'Film-Noir': 1,
#   'Western': 2,
#   'War': 1},
#  996: {'Drama': 12,
#   'Romance': 9,
#   'Comedy': 10,
#   'Mystery': 2,
#   'Thriller': 10,
#   'Crime': 5,
#   'Action': 7,
#   'War': 3,
#   'Adventure': 5,
#   'IMAX': 2,
#   'Sci-Fi': 3,
#   'Musical': 3,
#   'Animation': 2,
#   'Children': 2,
#   'Western': 1,
#   'Horror': 1,
#   'Fantasy': 1},
#  997: {'Crime': 25,
#   'Mystery': 10,
#   'Thriller': 21,
#   'Drama': 34,
#   'Comedy': 6,
#   'Romance': 7,
#   'Action': 19,
#   'Adventure': 7,
#   'War': 5,
#   'Fantasy': 5,
#   'Film-Noir': 1,
#   'IMAX': 3,
#   'Sci-Fi': 3,
#   'Western': 1},
#  998: {'Action': 8,
#   'Crime': 14,
#   'Thriller': 8,
#   'Drama': 53,
#   'Romance': 29,
#   'Comedy': 27,
#   'War': 10,
#   'Adventure': 11,
#   'IMAX': 3,
#   'Animation': 4,
#   'Children': 7,
#   'Musical': 14,
#   'Fantasy': 5,
#   'Mystery': 4,
#   'Sci-Fi': 2,
#   'Western': 3,
#   'Film-Noir': 1},
#  999: {'Drama': 4,
#   'Romance': 3,
#   'Crime': 1,
#   'Action': 3,
#   'Adventure': 2,
#   'Sci-Fi': 2,
#   'Mystery': 1,
#   'Thriller': 2,
#   'Comedy': 2,
#   'Fantasy': 2,
#   'Children': 1,
#   'Musical': 1},
#  1000: {'Action': 20,
#   'Adventure': 9,
#   'Animation': 3,
#   'Sci-Fi': 17,
#   'Horror': 2,
#   'Thriller': 14,
#   'Crime': 7,
#   'Drama': 12,
#   'Fantasy': 4,
#   'Mystery': 7,
#   'Romance': 1,
#   'IMAX': 9,
#   'Comedy': 1},
#  ...}

# %%
# Calcular las k categorías más vistas por cada usuario
k = 3
top_k_genres_data = []

# Itera sobre cada usuario en user_genre_counts
for user_id, genres in user_genre_counts.items():
   # Ordenar los géneros por el conteo en orden descendente y tomar los k más altos
   sorted_genres = sorted(genres.items(), key=lambda x: x[1], reverse=True)[:k]
   for genre, _ in sorted_genres:
    top_k_genres_data.append({
        'userId': user_id,
        'genre_principal': genre,
        'count': genres[genre]
    })


top_k_3_categories_total = pd.DataFrame(top_k_genres_data)

# Mostrar los resultados
print("Top k = 3 géneros más vistos por usuario:")
top_k_3_categories_total
# Out:
# Top k = 3 géneros más vistos por usuario:
#         userId genre_principal  count
# 0            1       Adventure     42
# 1            1         Fantasy     39
# 2            1          Action     35
# 3            2          Sci-Fi     22
# 4            2          Action     19
# ...        ...             ...    ...
# 415461  138492           Drama     15
# 415462  138492         Romance     12
# 415463  138493           Drama     98
# 415464  138493          Comedy     78
# 415465  138493          Action     54
#
# [415466 rows x 3 columns]

# %%
# Calcular las k categorías más vistas por cada usuario
k = 5
top_k_genres_data = []

# Itera sobre cada usuario en user
for user_id, genres in user_genre_counts.items():
  # Ordenar los los géneros por el conteo en orden descendente y tomar los k más altos
   sorted_genres = sorted(genres.items(), key=lambda x: x[1], reverse=True)[:k]
   for genre, _ in sorted_genres:
    top_k_genres_data.append({
        'userId': user_id,
        'genre_principal': genre,
        'count': genres[genre]
    })


top_k_5_categories_total = pd.DataFrame(top_k_genres_data)

# Mostrar los resultados
print("Top k = 5 géneros más vistos por usuario:")
top_k_5_categories_total
# Out:
# Top k = 5 géneros más vistos por usuario:
#         userId genre_principal  count
# 0            1       Adventure     42
# 1            1         Fantasy     39
# 2            1          Action     35
# 3            1        Thriller     23
# 4            1          Horror     22
# ...        ...             ...    ...
# 692331  138493           Drama     98
# 692332  138493          Comedy     78
# 692333  138493          Action     54
# 692334  138493       Adventure     51
# 692335  138493        Thriller     48
#
# [692336 rows x 3 columns]

# %%
# Calcular las k categorías más vistas por cada usuario
k = 7
top_k_genres_data = []

# Itera sobre cada usuario en user
for user_id, genres in user_genre_counts.items():
  # Ordenar los los géneros por el conteo en orden descendente y tomar los k más altos
   sorted_genres = sorted(genres.items(), key=lambda x: x[1], reverse=True)
   for genre, _ in sorted_genres:
    top_k_genres_data.append({
        'userId': user_id,
        'genre_principal': genre,
        'count': genres[genre]
    })


top_k_7_categories_total = pd.DataFrame(top_k_genres_data)

# Mostrar los resultados
print("Top k = 7 géneros más vistos por usuario:")
top_k_7_categories_total
# Out:
# Top k = 7 géneros más vistos por usuario:
#          userId genre_principal  count
# 0             1       Adventure     42
# 1             1         Fantasy     39
# 2             1          Action     35
# 3             1        Thriller     23
# 4             1          Horror     22
# ...         ...             ...    ...
# 2066725  138493            IMAX      7
# 2066726  138493             War      6
# 2066727  138493         Western      4
# 2066728  138493       Film-Noir      2
# 2066729  138493     Documentary      1
#
# [2066730 rows x 3 columns]

# %%
print(f"cantidad de categorias distintas con k=7: {top_k_7_categories_total['genre_principal'].nunique()}")
print(f"cantidad de categorias distintas con k=5: {top_k_5_categories_total['genre_principal'].nunique()}")
print(f"cantidad de categorias distintas con k=3: {top_k_3_categories_total['genre_principal'].nunique()}")
# Out:
# cantidad de categorias distintas con k=7: 20
# cantidad de categorias distintas con k=5: 19
# cantidad de categorias distintas con k=3: 19

# %% [markdown]
# Ahora con estos datos los graficamos

# %%
import matplotlib.pyplot as plt

# Lista de DataFrames y valores de K para iterar
top_k_dfs = [top_k_3_categories_total, top_k_5_categories_total, top_k_7_categories_total]
k_values = [3, 5, 7]

# Crear la figura y los ejes para la grilla de gráficos (2 filas, 3 columnas)
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

for i, (top_k_df, k) in enumerate(zip(top_k_dfs, k_values)):
    # Gráfico 1: Cantidad de usuarios que tienen cada género en su top K
    genre_user_count = top_k_df['genre_principal'].value_counts()
    axes[0, i].bar(genre_user_count.index, genre_user_count.values, color='skyblue')
    axes[0, i].set_title(f"Cantidad de Usuarios con Cada Género en su Top {k}")
    axes[0, i].set_xlabel("Género")
    axes[0, i].set_ylabel("Cantidad de Usuarios")
    axes[0, i].tick_params(axis='x', rotation=90)

    # Agrupar por genero principal para saber la cantidad de peliculas tiene el top k
    group_movie_by_genre = top_k_df.groupby('genre_principal')['count'].sum()
    # Ordenar por values
    group_movie_by_genre = group_movie_by_genre.sort_values(ascending=False)

    # Gráfico 2: Cantidad de peliculas por género en usuarios del top K
    axes[1, i].bar(group_movie_by_genre.index, group_movie_by_genre.values, color='salmon')
    axes[1, i].set_title(f"Cantidad de Peliculas por Género en Usuarios del Top {k}")
    axes[1, i].set_xlabel("Género")
    axes[1, i].set_ylabel("Cantidad de Peliculas")
    axes[1, i].tick_params(axis='x', rotation=90)

# Ajustar el layout para mejor visualización
plt.tight_layout()
plt.show()

# %% [markdown]
# Vemos que la cantidad de generos no cambian segun la cantidad de k's. Pero si la cantidad
